# %%
import pandas as pd
import nltk
from nltk.corpus import wordnet
from tqdm import tqdm
import gensim.downloader as api
from gensim.models import KeyedVectors
import numpy as np
from scipy.spatial.distance import cosine
from fuzzywuzzy import process

# Load pre-trained word embeddings
word_vectors = api.load("glove-wiki-gigaword-100")

# Load your dataset
df = pd.read_csv('final_data_exploration.csv')

# # Expanded manufacturing taxonomy
# manufacturing_taxonomy = {
#     "equipment": ["machine", "tool", "device", "gauge", "lamp", "filament", "wire", "desk", "station", "nut", "chipper", "sander", "grinder", "press", "CNC", "drill", "mixer", "saw", "chisel", "caliper", "bolt", "key", "stand", "hook", "pliers", "lathe", "oscilloscope", "feeler", "milling", "jack", "crane", "clamp", "screw", "gage", "mill", "cutter", "workbench", "mallet", "whiteout", "dispenser", "voltmeter", "chainsaw", "anvil", "horseshoe", "corkscrew", "vial", "pin", "wrench", "square", "tailstock", "secateur", "knurling", "roadheader", "rasper", "telehandler", "trephine", "fissurometer", "optometer"],
#     "process": ["manufacturing", "assembly", "fabrication", "casting", "printing", "welding", "chopping", "wiring", "foundry", "molding", "processing", "snow blower", "track hardware", "rail fastening", "grinding", "milling", "drilling", "cutting", "sawing", "pumping", "clinching", "imprinting", "stamping", "damascening", "enchain"],
#     "material": ["metal", "plastic", "composite", "brick", "wood", "rope", "ceramic", "mold", "steel", "material", "paint", "marble", "concrete", "rail", "track"],
#     "personnel": ["worker", "operator", "engineer", "welder", "crewmate", "jeweller"],
#     "quality": ["inspection", "testing", "measurement", "gage", "gauge"],
#     "safety": ["protection", "hazard", "precaution", "helmet", "muff", "protector", "light", "safety", "mask", "voltage detector", "cone", "interlock"],
#     "maintenance": ["repair", "upkeep", "sander", "grinder", "maintenance", "threadlocker"],
#     "logistics": ["transport", "shipping", "truck", "vehicle", "utility", "clip", "carabiner", "twowheeler"],
#     "automation": ["control", "CNC", "robot", "automated", "process", "computer numerical"],
#     "electrical": ["voltage", "power supply", "bulb", "halogen", "incandescent", "voltmeter"],
#     "specialized": ["cowcatcher", "smithingmark", "dheesterboom", "kailyard"],
#     "historical": ["dorfmuseum", "industriedenkmal", "wehrhahn"],
# }

manufacturing_taxonomy = {  
     "machines": ["CNC", "press", "drill", "mixer", "lathe", "mill", "chainsaw", "roadheader", "telehandler", "snow blower", "pump"],
    "tools": ["chipper", "sander", "grinder", "chisel", "pliers", "mallet", "cutter", "wrench", "saw", "secateur", "rasper", "jack", "crane", "clip", "carabiner"],
    "quality": ["gauge", "gage", "caliper", "oscilloscope", "feeler", "voltmeter", "square", "optometer", "fissurometer", "inspection", "testing", "measurement"],
    "fasteners": ["nut", "bolt", "screw", "hook", "clamp", "pin", "rail fastening"],
    "electrical": ["lamp", "filament", "wire", "bulb", "halogen", "incandescent", "power supply", "voltage detector"],
    "safety": ["helmet", "muff", "protector", "mask", "cone", "interlock"],
    "specialized": ["anvil", "horseshoe", "corkscrew", "knurling", "trephine","cowcatcher", "smithingmark", "dheesterboom"],
    "processes": ["manufacturing", "assembly", "fabrication", "casting", "printing", "welding", "chopping", "wiring", "foundry", "molding", "processing", "grinding", "milling", "drilling", "cutting", "sawing", "pumping", "clinching", "imprinting", "stamping", "damascening", "enchain"],
    "materials": ["metal", "plastic", "composite", "brick", "wood", "rope", "ceramic", "mold", "steel", "paint", "marble", "concrete", "rail", "track"],
    "maintenance": ["repair", "upkeep", "threadlocker", "worker", "operator", "engineer", "welder", "crewmate", "jeweller", "desk", "station", "workbench", "stand", "control", "robot", "automated", "process", "computer numerical", "transport", "shipping", "truck", "vehicle", "utility", "twowheeler"],
    "miscellaneous": ["dorfmuseum", "industriedenkmal", "wehrhahn", "kailyard"]
}

def analyze_label(label):
    return label.lower().split()

df['analyzed_labels'] = df['label'].apply(analyze_label)

def find_most_similar_category(concept, categories, threshold=0.3):
    if concept in word_vectors.key_to_index:
        similarities = []
        for category in categories:
            if category in word_vectors.key_to_index:
                similarity = 1 - cosine(word_vectors[concept], word_vectors[category])
                if similarity > threshold:
                    similarities.append((category, similarity))
        if similarities:
            return max(similarities, key=lambda x: x[1])[0]
    return None

def fuzzy_match(word, category_terms, threshold=80):
    matches = process.extractBests(word, category_terms, score_cutoff=threshold)
    return matches[0][0] if matches else None

def map_to_taxonomy(concepts, taxonomy):
    for i in range(len(concepts)):
        concept = concepts[i]
        
        # Direct match
        for category, terms in taxonomy.items():
            if concept in terms:
                return category
        
        # Fuzzy match
        for category, terms in taxonomy.items():
            fuzzy_match_result = fuzzy_match(concept, terms)
            if fuzzy_match_result:
                return category
        
        # Word similarity
        category = find_most_similar_category(concept, taxonomy.keys())
        if category:
            return category
        
        # Check word combinations
        if i < len(concepts) - 1:
            two_word_concept = concepts[i] + " " + concepts[i+1]
            for category, terms in taxonomy.items():
                if two_word_concept in terms:
                    return category
    
    # Fallback: return the category with the highest average similarity
    avg_similarities = []
    for category, terms in taxonomy.items():
        similarities = [word_vectors.similarity(concept, term) for concept in concepts for term in terms if concept in word_vectors.key_to_index and term in word_vectors.key_to_index]
        if similarities:
            avg_similarities.append((category, np.mean(similarities)))
    
    if avg_similarities:
        return max(avg_similarities, key=lambda x: x[1])[0]
    
    # If still unknown, assign to the most common category
    return "miscellaneous"

df['taxonomy_label'] = df['analyzed_labels'].apply(lambda concepts: map_to_taxonomy(concepts, manufacturing_taxonomy))

# Print statistics
print(df['taxonomy_label'].value_counts(normalize=True))

# Check remaining unknown labels
unknown_labels = df[df['taxonomy_label'] == 'unknown']['label'].unique()
print("\nSample of remaining 'unknown' labels:")
print(unknown_labels[:20])  # Print first 20 unknown labels

# Print absolute counts
print("\nAbsolute counts:")
print(df['taxonomy_label'].value_counts())
# Out:
# taxonomy_label
# machines         0.164671
# tools            0.158405
# processes        0.112098
# fasteners        0.107077
# materials        0.099695
# quality          0.099438
# electrical       0.087035
# maintenance      0.065019
# safety           0.062401
# specialized      0.038797
# miscellaneous    0.005365
# Name: proportion, dtype: float64
#
# Sample of remaining 'unknown' labels:
# []
#
# Absolute counts:
# taxonomy_label
# machines         3837
# tools            3691
# processes        2612
# fasteners        2495
# materials        2323
# quality          2317
# electrical       2028
# maintenance      1515
# safety           1454
# specialized       904
# miscellaneous     125
# Name: count, dtype: int64

# %%
# Save the results
df.to_csv('kevin__data_exploration_taxonomy.csv', index=False)

# %%
# import pandas as pd
# import nltk
# from nltk.corpus import wordnet
# from tqdm import tqdm
# import gensim.downloader as api
# from gensim.models import KeyedVectors
# import numpy as np
# from scipy.spatial.distance import cosine

# # Download necessary NLTK data
# nltk.download('wordnet')
# nltk.download('averaged_perceptron_tagger')

# # Load pre-trained word embeddings
# print("Loading word embeddings...")
# word_vectors = api.load("glove-wiki-gigaword-100")

# # Load your dataset
# df = pd.read_csv('final_data_exploration.csv')

# # Define a basic manufacturing taxonomy
# manufacturing_taxonomy = {  
#      "machines": ["CNC", "press", "drill", "mixer", "lathe", "mill", "chainsaw", "roadheader", "telehandler", "snow blower", "pump"],
#     "tools": ["chipper", "sander", "grinder", "chisel", "pliers", "mallet", "cutter", "wrench", "saw", "secateur", "rasper", "jack", "crane", "clip", "carabiner"],
#     "quality": ["gauge", "gage", "caliper", "oscilloscope", "feeler", "voltmeter", "square", "optometer", "fissurometer", "inspection", "testing", "measurement"],
#     "fasteners": ["nut", "bolt", "screw", "hook", "clamp", "pin", "rail fastening"],
#     "electrical": ["lamp", "filament", "wire", "bulb", "halogen", "incandescent", "power supply", "voltage detector"],
#     "safety": ["helmet", "muff", "protector", "mask", "cone", "interlock"],
#     "specialized": ["anvil", "horseshoe", "corkscrew", "knurling", "trephine","cowcatcher", "smithingmark", "dheesterboom"],
#     "processes": ["manufacturing", "assembly", "fabrication", "casting", "printing", "welding", "chopping", "wiring", "foundry", "molding", "processing", "grinding", "milling", "drilling", "cutting", "sawing", "pumping", "clinching", "imprinting", "stamping", "damascening", "enchain"],
#     "materials": ["metal", "plastic", "composite", "brick", "wood", "rope", "ceramic", "mold", "steel", "paint", "marble", "concrete", "rail", "track"],
#     "maintenance": ["repair", "upkeep", "threadlocker", "worker", "operator", "engineer", "welder", "crewmate", "jeweller", "desk", "station", "workbench", "stand", "control", "robot", "automated", "process", "computer numerical", "transport", "shipping", "truck", "vehicle", "utility", "twowheeler"],
#     "miscellaneous": ["dorfmuseum", "industriedenkmal", "wehrhahn", "kailyard"]
# }

# # Step 1: Label Analysis
# def analyze_label(label):
#     tokens = nltk.word_tokenize(label)
#     pos_tags = nltk.pos_tag(tokens)
    
#     concepts = []
#     current_concept = []
    
#     for word, pos in pos_tags:
#         if pos.startswith('NN') or pos.startswith('JJ'):
#             current_concept.append(word.lower())
#         else:
#             if current_concept:
#                 concepts.append(' '.join(current_concept))
#                 current_concept = []
    
#     if current_concept:
#         concepts.append(' '.join(current_concept))
    
#     return concepts

# df['analyzed_labels'] = df['label'].apply(analyze_label)

# # Step 2: Taxonomy Creation
# class TaxonomyNode:
#     def __init__(self, name):
#         self.name = name
#         self.children = {}
    
#     def add_child(self, child_name):
#         if child_name not in self.children:
#             self.children[child_name] = TaxonomyNode(child_name)
#         return self.children[child_name]

# root = TaxonomyNode('root')

# # Initialize the taxonomy with the manufacturing-specific categories
# for category in manufacturing_taxonomy.keys():
#     root.add_child(category)

# # Create a frequency dictionary for concepts
# concept_freq = {}
# for concepts in df['analyzed_labels']:
#     for concept in concepts:
#         concept_freq[concept] = concept_freq.get(concept, 0) + 1

# # Sort concepts by frequency
# sorted_concepts = sorted(concept_freq.items(), key=lambda x: x[1], reverse=True)

# # Function to find the most similar category
# def find_most_similar_category(concept, categories):
#     if concept in word_vectors.key_to_index:
#         similarities = [
#             (category, 1 - cosine(word_vectors[concept], word_vectors[category]))
#             for category in categories
#             if category in word_vectors.key_to_index
#         ]
#         if similarities:
#             return max(similarities, key=lambda x: x[1])[0]
#     return None

# # Create taxonomy based on frequency, word similarity, and manufacturing categories
# for concept, _ in sorted_concepts:
#     parts = concept.split()
#     current_node = root
#     for part in parts:
#         # Check if the part fits into any existing manufacturing category
#         category = find_most_similar_category(part, manufacturing_taxonomy.keys())
#         if category and category in current_node.children:
#             current_node = current_node.children[category]
#         current_node = current_node.add_child(part)

# # Add subcategories to their respective categories
# for category, subcategories in manufacturing_taxonomy.items():
#     category_node = root.children[category]
#     for subcategory in subcategories:
#         if subcategory not in category_node.children:
#             category_node.add_child(subcategory)

# # Step 3: Data Annotation
# def get_path(node, label):
#     label_parts = label.lower().split()
#     path = ['root']
#     current_node = node
    
#     for part in label_parts:
#         if part in current_node.children:
#             path.append(part)
#             current_node = current_node.children[part]
#         else:
#             # Find the most similar child using word embeddings
#             most_similar = None
#             highest_similarity = -1
#             for child in current_node.children:
#                 if child in word_vectors.key_to_index and part in word_vectors.key_to_index:
#                     similarity = word_vectors.similarity(child, part)
#                     if similarity > highest_similarity:
#                         highest_similarity = similarity
#                         most_similar = child
            
#             if most_similar and highest_similarity > 0.5:
#                 path.append(most_similar)
#                 current_node = current_node.children[most_similar]
#             else:
#                 break
    
#     return path if len(path) > 1 else None

# df['hierarchical_label'] = df['label'].apply(lambda x: get_path(root, x))

# # Save the annotated dataset
# df.to_csv('annotated_dataset.csv', index=False)

# # Print the taxonomy
# def print_taxonomy(node, level=0):
#     print('  ' * level + node.name)
#     for child in node.children.values():
#         print_taxonomy(child, level + 1)

# print("Taxonomy structure:")
# print_taxonomy(root)

# # Validation step
# def validate_taxonomy(node, path=[]):
#     issues = []
#     current_path = path + [node.name]
    
#     # Check for very deep branches (e.g., more than 5 levels)
#     if len(current_path) > 5:
#         issues.append(f"Deep branch detected: {' > '.join(current_path)}")
    
#     # Check for nodes with too many children (e.g., more than 10)
#     if len(node.children) > 10:
#         issues.append(f"Node with many children: {' > '.join(current_path)}, Children count: {len(node.children)}")
    
#     # Recursive call for children
#     for child in node.children.values():
#         issues.extend(validate_taxonomy(child, current_path))
    
#     return issues

# print("\nValidating taxonomy...")
# validation_issues = validate_taxonomy(root)

# if validation_issues:
#     print("Validation issues found:")
#     for issue in validation_issues:
#         print(f"- {issue}")
# else:
#     print("No validation issues found.")

# # Manual adjustment function
# def manual_adjust_taxonomy():
#     while True:
#         action = input("\nEnter action (add/move/delete/done): ").lower()
#         if action == 'done':
#             break
#         elif action in ['add', 'move', 'delete']:
#             path = input("Enter path (e.g., root > equipment > machine): ").split(' > ')
#             if action in ['move', 'delete']:
#                 node_name = path.pop()
#             if action == 'add':
#                 new_node = input("Enter new node name: ")
            
#             current_node = root
#             for node in path:
#                 if node in current_node.children:
#                     current_node = current_node.children[node]
#                 else:
#                     print(f"Path not found: {' > '.join(path)}")
#                     break
#             else:
#                 if action == 'add':
#                     current_node.add_child(new_node)
#                     print(f"Added {new_node} to {' > '.join(path)}")
#                 elif action == 'move':
#                     if node_name in current_node.children:
#                         node_to_move = current_node.children.pop(node_name)
#                         new_parent = input("Enter new parent path: ").split(' > ')
#                         new_current = root
#                         for new_node in new_parent:
#                             if new_node in new_current.children:
#                                 new_current = new_current.children[new_node]
#                             else:
#                                 print(f"New parent path not found: {' > '.join(new_parent)}")
#                                 break
#                         else:
#                             new_current.children[node_name] = node_to_move
#                             print(f"Moved {node_name} to {' > '.join(new_parent)}")
#                     else:
#                         print(f"Node not found: {node_name}")
#                 elif action == 'delete':
#                     if node_name in current_node.children:
#                         del current_node.children[node_name]
#                         print(f"Deleted {node_name} from {' > '.join(path)}")
#                     else:
#                         print(f"Node not found: {node_name}")
#         else:
#             print("Invalid action. Please enter add, move, delete, or done.")

# print("\nManual Taxonomy Adjustment")
# print("You can now manually adjust the taxonomy.")
# # manual_adjust_taxonomy()

# # # Re-annotate the dataset after manual adjustments
# # df['hierarchical_label'] = df['label'].apply(lambda x: get_path(root, x))

# # # Save the final annotated dataset
# # df.to_csv('final_annotated_dataset.csv', index=False)

# # print("\nFinal Taxonomy structure:")
# print_taxonomy(root)

# # print("\nAnnotation complete. Final dataset saved as 'final_annotated_dataset.csv'")
# Out:
# [nltk_data] Downloading package wordnet to /home/trkosire/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/trkosire/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Loading word embeddings...
# Taxonomy structure:
# root
#   machines
#     lathe
#       information
#       operator
#       chuck
#         insert
#       tailstock
#         assembly
#         center
#       tool
#         post
#       way
#       cutter
#       center
#       carriage
#       headstock
#         assembly
#       bit
#       tail
#         stock
#       compound
#         rest
#       workpiece
#       mandrel
#       goalpost
#       dog
#       gearbox
#       control
#       tumbler
#       head
#         stock
#       chunk
#       work
#         piece
#       outside
#       feedstock
#       jaw
#       clamp
#       machine
#     machine
#       tool
#       screw
#       shop
#         wheel
#       cutter
#         storage
#       phonography
#       pres
#       workpiece
#       rotary
#         table
#       table
#       collet
#       chuck
#       tread
#       tooling
#       motor
#       surface
#       stone
#         chisel
#           bit
#       part
#         diagram
#       label
#       loader
#       center
#       hammer
#         peeing
#       wheel
#       boring
#         tool
#       notification
#         light
#     hand
#       tool
#       chisel
#         blade
#       press
#       stone
#         chisel
#       clamp
#       crank
#         drill
#         machine
#         circle
#           cutter
#       pres
#       sander
#       power
#         drill
#         tool
#       auger
#       riveter
#       shield
#       hook
#       file
#       juicer
#       wheel
#       winch
#       pruner
#       hole
#         saw
#       light
#       wire
#       grinder
#       pallet
#         truck
#       ice
#         auger
#       thread
#         tapper
#       axe
#     wheel
#       bolt
#       nut
#       grinder
#       lock
#       lathe
#       clamp
#       head
#       trencher
#       bearing
#       crank
#     milling
#       machine
#       cutter
#       wheel
#       proces
#     grinder
#       spark
#     mask
#     chain
#       coupling
#       pulley
#         hook
#       link
#         fence
#       support
#       tool
#     mortar
#     pie
#     windmill
#       tool
#       cutter
#     washer
#       hardware
#     foundry
#       ladle
#       crucible
#       crane
#       bucket
#       company
#     e
#       prison
#       clip
#       enter
#     computer
#       numerical
#         control
#           machining
#             center
#           machine
#       port
#       mouse
#     cutter
#       grinder
#     nameplate
#     compact
#       fluorescent
#         light
#           bulb
#         lightbulb
#       directional
#         drill
#       fluorescence
#         light
#           bulb
#     handheld
#       circular
#       masonry
#         drill
#       drill
#       chop
#       juicer
#       tool
#       tape
#         dispenser
#       grinder
#       arc
#         cutter
#       plasma
#         arc
#           cutter
#     sander
#     square
#       nut
#       tool
#       ruler
#       photo
#       nail
#       head
#         bolt
#       thread
#       bit
#       screwdriver
#         bit
#       drive
#         screw
#       key
#       wrench
#       pattern
#         file
#     robot
#       arm
#         end
#           effector
#       hand
#       endeffector
#       welder
#     bell
#     roller
#       bearing
#       cone
#         drill
#           bit
#       compactor
#       bit
#       conveyor
#       belt
#       pres
#     laser
#       cutter
#       cutting
#         machine
#       engraver
#       processing
#         machine
#       welding
#       outline
#       gantry
#       ash
#         power
#           hammer
#             label
#       cut
#         wood
#           router
#     rotary
#       hammer
#         drill
#       printing
#         press
#         pres
#       tool
#         set
#         bit
#       table
#       bit
#       snowplow
#       drill
#         bit
#       snow
#         plow
#       cutter
#         tool
#       press
#         tablet
#       instrument
#       scissors
#       drilling
#         rig
#       driving
#         rig
#       grinder
#         tooling
#       burr
#     clip
#     needle
#       scaler
#       roller
#         bearing
#       gun
#       gauge
#       bearing
#     electronic
#       workbench
#       component
#       repair
#       assembly
#       lock
#       device
#       storage
#       machine
#       power
#         source
#       testing
#         equipment
#       key
#         fob
#     pronto
#     chop
#     jig
#       saw
#     tube
#       production
#       cleaning
#       maintenance
#     oscilloscope
#     bow
#       saw
#       drill
#       car
#         key
#     stump
#       grinder
#       cutter
#     bucket
#     disk
#       drive
#     confocal
#       microscope
#     roll
#       forming
#       slitting
#         machine
#       snow
#         blower
#       fed
#         heat
#           pres
#     peg
#     wooden
#       workpiece
#       mortar
#       nail
#       clothe
#         peg
#       dowel
#       workbench
#       movable
#         type
#       door
#       lathe
#       hammer
#       hand
#       model
#         crankshaft
#       pencil
#       piece
#       shoe
#         machine
#       pres
#       machine
#     device
#     relay
#       circuit
#     microscope
#     potter
#       wheel
#     towel
#     portable
#       hand
#         coffee
#           mill
#       forge
#       sawmill
#       automatic
#         coffee
#           mill
#       soldering
#         iron
#       mini
#         soldering
#           iron
#     boom
#       lift
#         bucket
#       arm
#     printer
#       type
#         box
#       lettertype
#     zip
#       tie
#     racket
#       strap
#     mini
#       precision
#         screwdriver
#           set
#       table
#         saw
#       lathe
#       excavator
#       saw
#     pan
#     gantry
#       crane
#       lift
#       milling
#         machine
#     tack
#     punch
#       tool
#       pres
#       card
#       ticket
#         marker
#       diagram
#     shop
#       floor
#       smith
#         mark
#       air
#         line
#     turnstile
#     drum
#       compactor
#       sander
#       motor
#     barrel
#       nut
#       sander
#     pocket
#       knife
#       corkscrew
#     replica
#     coin
#       minting
#         pres
#     phone
#     cookie
#       cutter
#     boring
#       machine
#         drill
#       drill
#     switch
#       panel
#     acorn
#       nut
#     rat
#     gage
#       block
#     serbia
#     flashlight
#     precision
#       tool
#       engineering
#       component
#       screwdriver
#       drilling
#       pick
#     wringer
#       washer
#     crank
#       shaft
#       press
#       handle
#     t
#       ruler
#     automatic
#       tool
#         changer
#       die
#         cutter
#       wood
#         paving
#           machine
#       center
#         punch
#       lathe
#       welder
#       welding
#         machine
#       big
#         welding
#           machine
#     arcade
#     bras
#       tube
#     pastry
#       cutter
#     lumberjack
#     jar
#       clasp
#     die
#       casting
#       pres
#       handle
#       forging
#       plate
#       forge
#         pres
#     dump
#       truck
#         lift
#           gate
#     bubble
#       level
#       gauge
#     dial
#       indicator
#       lock
#     hollow
#       steel
#         punch
#     rack
#     u
#       smitgemaal
#       diamond
#         cording
#           drill
#             rig
#     rainbow
#       wire
#         ribbon
#           cable
#     vacuum
#       pump
#       seal
#       clamp
#       hose
#     snap
#       ring
#         pliers
#       fastener
#     block
#     bag
#     compass
#     cart
#     miniature
#       screwdriver
#         set
#     console
#     pot
#     sardine
#     curtain
#     mixer
#     dispenser
#     shutter
#       dog
#     laptop
#       keyboard
#       hinge
#     tablet
#       press
#       pres
#     ticket
#       puncher
#     robotic
#       welder
#       arm
#       big
#         welder
#       welding
#       wire
#         em
#     ring
#     jog
#       telescopic
#         boom
#           lift
#     chip
#       assembly
#       guard
#     arrowhead
#       camp
#         doe
#           piste
#     wired
#       power
#         tool
#     system
#     slide
#       rule
#     breaker
#       box
#     pet
#       preform
#     sink
#     stack
#     digital
#       caliper
#       scale
#       gramophone
#         recorder
#       soldering
#         station
#       tin
#       frequency
#         counter
#       lock
#       level
#       control
#         panel
#     teller
#       stop
#     n
#       mask
#     comet
#       motorsager
#     keypad
#     em
#       machine
#     laundry
#       press
#     rocket
#       boomer
#         e
#     pour
#       foundry
#         ladle
#     razor
#       blade
#         sharpener
#       sharpener
#       scraper
#       knife
#         set
#     hang
#       xiaoquan
#         store
#           hong
#     vain
#     compas
#     ultra
#       gel
#     calendar
#       machine
#     euro
#       cylinder
#         lock
#     mobile
#       boring
#         machine
#       chipper
#       crane
#     video
#       measuring
#         system
#     firework
#       port
#     cardboard
#       box
#     casting
#       machine
#     palm
#       sander
#     frantic
#       fermenting
#     kensington
#       lock
#     chunghwa
#       post
#         box
#     apple
#       cider
#         pres
#     q
#       flange
#         vacuum
#           tee
#     caterpillar
#       snow
#       c
#         hydraulic
#           excavator
#       hydraulic
#         shovel
#           loader
#     ton
#       hydraulic
#         pres
#       ironworker
#     mule
#       wolxheim
#     zoom
#       boom
#     egg
#       beater
#     mock
#     kiln
#       design
#     fancy
#       csc
#         controller
#           panel
#     bread
#       slicer
#     duplex
#       wheel
#         lathe
#     bearer
#       csc
#         plasma
#           cutter
#     mega
#       arc
#         welding
#           machine
#     injection
#       molding
#         machine
#     keg
#       wetter
#         mincer
#       gold
#         bar
#       silver
#         ingot
#     crushing
#       mill
#     coupe
#       disc
#         hedge
#           trimmer
#     float
#       ism
#         cros
#     ti
#     toilet
#       paper
#     prototype
#       board
#     eccentric
#       press
#         tablet
#     clock
#     gras
#       flexipres
#     slot
#       cutter
#     suction
#       hose
#     dreamed
#       bit
#     haar
#       hung
#         door
#     assembly
#       system
#     mouse
#     clipper
#     hora
#       scientific
#         mixermill
#           m
#     gunstock
#       lathe
#     eraser
#     wager
#       electric
#         company
#           strike
#     la
#       csc
#         laser
#           cutting
#     cauldron
#     snack
#     turret
#       lathe
#     dine
#     ert
#       polecat
#         csc
#           punching
#             machine
#     arbor
#       pres
#     sharpie
#     kilogram
#       gold
#         bar
#     trump
#       csc
#         laser
#           cutter
#       trumabend
#         v
#           pres
#     card
#     thermometer
#     retro
#       system
#     lobster
#       clasp
#     bracelet
#     powered
#       hand
#         grinder
#     typewriter
#     candlestick
#     bump
#       key
#     telescope
#     ad
#       drive
#     clipboard
#     pack
#     blackjack
#       livery
#         stable
#     v
#       reciprocating
#     interchangeable
#       bit
#     bot
#     tag
#     automated
#       system
#     booth
#     tilt
#       hammer
#     mower
#       blade
#     souvenir
#     h
#       scheme
#         company
#     balloon
#       framing
#     fried
#       lohmann
#         gosh
#     doll
#       crawler
#         excavator
#     refill
#       staple
#     stool
#     tabletop
#       scroll
#     disco
#     neumann
#       va
#     reciprocating
#       saw
#     gravure
#       cylinder
#     spigot
#     faucet
#     moulin
#       lambert
#     duck
#       bill
#         pliers
#     CNC
#     press
#     drill
#     mill
#     chainsaw
#     roadheader
#     telehandler
#     snow blower
#     pump
#   tools
#     scissors
#     tool
#       bit
#       post
#       belt
#       chest
#       grinder
#       box
#       crib
#       battery
#       insert
#       bench
#       tip
#       end
#       kit
#       head
#       handler
#       organization
#       cabinet
#       holder
#       storage
#         area
#       presenter
#       cutter
#         grinder
#     hammer
#       drill
#       scale
#     anvil
#       hardy
#         tool
#     pestle
#     crawler
#       excavator
#       drill
#       machine
#     nail
#       gun
#       fastener
#       cutter
#       scissors
#       file
#       clipper
#       pneumatic
#         nailer
#           clip
#       clippers
#     hook
#       hand
#         tool
#     workbench
#     manual
#       metal
#         arc
#           welding
#       grinder
#       milling
#         machine
#         center
#       drill
#         pres
#       lathe
#       hand
#         drill
#       rivet
#         gun
#       miter
#       printing
#         pres
#       trip
#         hammer
#       hole
#         punch
#           pres
#       juicer
#       ice
#       chainsaw
#       circle
#         cutter
#       saw
#       caliper
#       tool
#       pres
#       shears
#     stone
#       mortar
#       cutter
#       cider
#         pres
#       chisel
#       bit
#       mill
#       grain
#         mill
#       wheel
#     blade
#       grinder
#       food
#         processor
#       holder
#       guard
#       assembly
#       tooth
#     gear
#       doc
#       train
#       shaft
#       motor
#       assembly
#       ring
#       metering
#       system
#       bearing
#       mechanism
#     forge
#       pres
#       bellow
#       hammer
#       tool
#       tong
#       material
#       furnace
#       billet
#       piece
#     blacksmith
#       shop
#         sherbert
#           hoover
#             nu
#         benicia
#           californium
#       tool
#       tong
#       hammer
#       unit
#       power
#         hammer
#     knife
#       sharpener
#       reinforce
#         diagonal
#           wire
#             cutter
#       multifoil
#       blade
#     jigsaw
#       rest
#     file
#       tool
#     keyhole
#     stick
#       welder
#         welder
#       welding
#         rod
#       weld
#     ladder
#     worm
#       gear
#       drive
#         circular
#     axe
#     crosscut
#       saw
#     workshop
#       equipment
#       setup
#       activity
#       generator
#     mound
#     hack
#       saw
#       burgomaster
#         csc
#           sheet
#             metal
#               bender
#     window
#       shutter
#       hinge
#     shredder
#       horticulture
#     indelible
#       insert
#       milling
#         cutter
#       csc
#         collet
#     grinding
#       mill
#       wheel
#     metalworking
#       tong
#     shovel
#       bucket
#         excavator
#       loader
#     loophole
#     log
#       splitter
#     claw
#       hammer
#       crane
#       machine
#       attachment
#       excavator
#     brush
#     spade
#       bit
#       drill
#         bit
#     statue
#     pad
#       lock
#     ratchet
#       strap
#       winch
#       screwdriver
#     scroll
#       saw
#     clothe
#       hanger
#       peg
#       pin
#     blacksmithing
#     honing
#     loader
#     frame
#     kitchen
#       tong
#       tool
#       scissors
#       gadget
#       knife
#     fork
#       lift
#     toolbox
#     bone
#     insert
#       bit
#     micro
#       line
#         electrician
#           screwdriver
#     shave
#       horse
#     instrument
#     corded
#       power
#         drill
#         grinder
#         tool
#     telescopic
#       boom
#         lift
#         crane
#       handler
#       crane
#       forklift
#     forging
#       pres
#       tong
#       hammer
#     drawer
#     antique
#       grinder
#       printing
#         pres
#       tool
#       screwdriver
#       corkscrew
#       chest
#       lathe
#       thicknes
#         gauge
#       key
#       drill
#         pres
#       pres
#     object
#     woodworking
#       machine
#     paintbrush
#     locate
#     typography
#     kit
#       dockland
#         museum
#     tooth
#     herder
#       leaden
#     sponge
#       forceps
#     accessory
#     toolkit
#     carpentry
#       lathe
#     hardware
#       organizer
#       storage
#     intend
#       cut
#     attach
#       dilator
#         wood
#           chipper
#     custom
#       wiring
#       metal
#         part
#     twist
#       drill
#         bit
#       tie
#     woodwork
#     desk
#       lamp
#       light
#     butcher
#     pointing
#     cam
#       probe
#       machine
#       lock
#     use
#       global
#         explorer
#           tag
#     gilder
#     tab
#     crab
#       shell
#         scissors
#     pillar
#     font
#       block
#     wikipedia
#       key
#         accessory
#     grub
#     mizutani
#     hatchet
#     sword
#     platform
#     draper
#       chainsaw
#     craftsman
#       miter
#       screwdriver
#       power
#         drill
#       chainsaw
#       circular
#     stork
#       stuttgart
#         temperature
#           gauge
#     teach
#       pendant
#     grist
#       mill
#     desktop
#       milling
#         machine
#     numerical
#       simulation
#     ax
#     boot
#     trick
#     bait
#     pinpoint
#       parcel
#         locker
#     artisan
#       craftsmanship
#     loose
#       wheel
#         nut
#           indicator
#     killer
#     calculator
#     wipe
#     ancient
#       shears
#     wallpaper
#     ram
#       pres
#     casement
#       window
#     chipper
#     sander
#     grinder
#     chisel
#     pliers
#     mallet
#     cutter
#     wrench
#     saw
#     secateur
#     rasper
#     jack
#     crane
#     clip
#     carabiner
#   quality
#     bit
#       set
#       driver
#       adapter
#       chuck
#       insert
#       shank
#     light
#       bulb
#         component
#       microscope
#       switch
#       pull
#       truck
#     key
#       ring
#       blank
#       fob
#       switch
#       cutter
#       rack
#       duplicator
#       duplication
#         machine
#       pad
#       tumbler
#       car
#         slot
#       card
#       hole
#     person
#       hand
#       wood
#     table
#       saw
#       vise
#       jig
#     ball
#       bearing
#         component
#         stationary
#           coupler
#         coupler
#         toy
#         cage
#         inner
#         outer
#         ball
#       peen
#         hammer
#       mill
#       lock
#     spirit
#       level
#     hard
#       hat
#       pressure
#         roller
#       point
#       rock
#         drilling
#           auger
#     glove
#       cut
#     work
#       glove
#       cell
#       bench
#       station
#       table
#       desk
#       rotary
#         cutter
#       light
#       instruction
#       vehicle
#       compact
#         circular
#           saw
#     band
#       saw
#     chili
#       screwdriver
#       hex
#         head
#       countersunk
#     personal
#       protective
#         equipment
#     level
#       hoist
#       cube
#     flat
#       head
#         screwdriver
#           bit
#       blade
#         screwdriver
#           bit
#       rail
#         car
#       drill
#         bit
#       screwdriver
#       nose
#         pliers
#       spade
#         hole
#           cutter
#       saw
#       washer
#       bit
#     black
#       smith
#         shop
#         tool
#         forge
#       pecker
#         v
#           mufti
#             tool
#               plu
#         rotary
#           hammer
#         kiln
#       iron
#         tee
#       malleable
#         cast
#           iron
#     historical
#       metalworking
#         lathe
#       scissors
#       lathe
#       lock
#       manufacturing
#       machine
#         tool
#     rock
#       drill
#         machine
#       drilling
#         machine
#       auger
#         bit
#       cutter
#     part
#       wash
#       stack
#       label
#       divider
#         cubby
#       bin
#     human
#       machine
#         interface
#       lift
#     big
#       weld
#       welder
#       welding
#         machine
#         torch
#       man
#         fortune
#           hep
#       beaver
#         drill
#           rig
#     skin
#       circular
#       protection
#       power
#         drill
#     tap
#       dy
#       die
#         handle
#       handle
#       set
#     snow
#       blower
#       thrower
#         truck
#       plow
#       remover
#     amazon
#       locker
#       pickup
#         station
#     coffee
#       grinder
#       maker
#       digital
#         lock
#     yellow
#       drilling
#         machine
#       juicer
#     woman
#       crosscut
#       mecklenburg
#     owe
#     handle
#       tool
#     shelf
#       bracket
#     lag
#       bolt
#     water
#       wheel
#       jet
#         cutter
#       pump
#       bottle
#       weenie
#       container
#       stick
#         welder
#       jetting
#       reflection
#     life
#       light
#         bulb
#     staple
#       fastener
#       sheet
#       gun
#       refill
#         stick
#       clip
#     test
#       light
#       tape
#       tube
#     disc
#       pad
#       hedge
#         trimmer
#       sander
#     ice
#       auger
#       core
#         drill
#       tong
#       saw
#       drilling
#         rig
#       pick
#       drill
#         auger
#     cider
#       press
#       pres
#     spring
#       lock
#         washer
#       snap
#         clip
#       clamp
#       power
#         hammer
#     vintage
#       printing
#         pres
#       pres
#       grinder
#       blow
#         torch
#       workbench
#       bandsaw
#       equipment
#       tool
#       coffee
#         grinder
#       hand
#       platen
#         pres
#       wooden
#         workbench
#       machinery
#       lathe
#       lithographic
#         pres
#           machine
#       electronic
#       pencil
#         sharpener
#       mill
#     meat
#       grinder
#       slicer
#       hook
#     type
#       case
#       crucible
#         furnace
#     hot
#       glue
#         gun
#       metal
#         billet
#       plate
#         welding
#       work
#         piece
#       glas
#       steel
#         bar
#         stock
#     orange
#       peel
#         grapple
#       hive
#         jacket
#     fish
#       hook
#     edge
#       runner
#         millstone
#       mill
#     scotch
#       tape
#       book
#         tape
#     sedan
#       machine
#         tool
#           plant
#     speed
#       square
#     draw
#       plate
#     stamp
#       metalworking
#     box
#       cutter
#         knife
#       beam
#         level
#       knife
#       mangle
#       tape
#         dispenser
#     eye
#       hook
#       bolt
#       protection
#       turnbuckle
#     stock
#       pile
#       material
#       metal
#         piece
#     olive
#       oil
#         mill
#         production
#       crusher
#     scale
#       breaker
#     combination
#       padlock
#       square
#       lock
#       machine
#       hammer
#         drill
#       drive
#         machine
#           screw
#       belt
#     hair
#       scissors
#     golden
#       spike
#         national
#           historical
#             park
#         ceremony
#       pavilion
#     correction
#       tape
#     cold
#       saw
#       weather
#         pie
#       piccolo
#         kraftformer
#           power
#             hammer
#       weld
#         epoxy
#       soldering
#         joint
#     central
#       pacific
#       machinery
#         mini
#           lathe
#     wet
#       fly
#         pattern
#     step
#       ladder
#       utrecht
#       stair
#     plate
#       bending
#         machine
#     label
#       printer
#     cool
#       white
#     warm
#       light
#     bottle
#       opener
#       preform
#       blank
#     spain
#     dollar
#       chainsaw
#       machine
#       rasentraktor
#     fan
#       blade
#     diamond
#       abrasive
#         tool
#       angle
#         grinder
#           disc
#       saw
#       wire
#       brick
#       band
#       anvil
#         cell
#       core
#         bit
#         drill
#           bit
#       coring
#         drill
#           rig
#     self
#       drilling
#         screw
#     way
#     stand
#     screen
#     spot
#       welding
#     cheap
#       grandam
#     china
#     luck
#       scissors
#     firmer
#       chisel
#     simple
#       full
#         metallic
#           corkscrew
#     production
#       line
#       facility
#     tomato
#       jg
#       model
#         arc
#           welder
#       welding
#         machine
#     sugar
#       tong
#       cane
#         press
#         crusher
#         mill
#     super
#       glue
#     crack
#       monitor
#       measurement
#         instrument
#       expansion
#         measurement
#           tool
#       gauge
#       width
#         gauge
#         monitor
#       monitoring
#         gauge
#     job
#       chainsaw
#       site
#     french
#       kri
#     ha
#       automation
#       csc
#         lathe
#         mill
#       milling
#         machine
#     skill
#       jigsaw
#     blue
#       tape
#       tack
#       rise
#       marker
#       wallpaper
#     blind
#       rivet
#     man
#       basket
#       auger
#       hole
#         cover
#     guide
#     grain
#       mill
#     cup
#       hook
#       hinge
#     high
#       speed
#         steel
#       bay
#       i
#         jacket
#       strength
#         contact
#           adhesive
#     horse
#       wheel
#     word
#       q
#         boring
#           mill
#     size
#     food
#       processor
#       grinder
#       processing
#         blade
#       extrusion
#       production
#     garden
#       shears
#       scissors
#       shredder
#         blade
#       hoe
#       tool
#         part
#     i
#       beam
#       cabinet
#         servo
#           inverter
#       tool
#         presenter
#     impact
#       power
#         hand
#           drill
#         drill
#       driver
#     juice
#       pres
#       reamer
#     color
#     white
#       image
#       background
#       photo
#       board
#     love
#       padlock
#     wine
#       opener
#       production
#       bottle
#       pres
#       press
#     print
#       shop
#       pres
#       block
#         die
#       machine
#       production
#     top
#       handle
#         chainsaw
#     technical
#       drawing
#     side
#       cutter
#       chip
#       pres
#     star
#       screw
#       driver
#         bit
#       cutter
#       head
#       bit
#     temperature
#       gauge
#     pool
#     cut
#       resistant
#         chap
#       rubber
#     girl
#     quality
#       image
#     grill
#       tong
#     fitting
#     batter
#     coat
#       hanger
#       rack
#       hook
#     best
#       france
#     fruit
#       pres
#       press
#     scientific
#       equipment
#     stable
#       saw
#       screwdriver
#       fatal
#         oscillating
#           multifoil
#       electric
#     product
#     rest
#     audio
#       machinery
#     italy
#     hockey
#       stick
#       tape
#       uniform
#     game
#       watch
#         hinge
#       console
#     mole
#       van
#         singraven
#     wish
#     garlic
#       pres
#     cheese
#       slicer
#     crown
#       wheel
#     plain
#       washer
#       bearing
#     universal
#       hand
#     leaf
#       blower
#       spring
#     host
#       press
#     vena
#       s
#         thicknes
#           planer
#     live
#       bait
#         vending
#           machine
#       center
#     tongue
#       guard
#     red
#       padlock
#       pushpin
#     energy
#       supply
#     mama
#       ingot
#       alloy
#         ingot
#     round
#     fact
#       square
#         paper
#           cutter
#     pop
#       rivet
#         gun
#     green
#       scissors
#       pushpin
#       masking
#         tape
#     angel
#       grinder
#     exact
#       knife
#     height
#       gage
#       gauge
#     cast
#       iron
#         door
#           knocker
#       shears
#     number
#       pad
#     whiskey
#       safe
#     reach
#       forklift
#     good
#       boy
#     win
#       bar
#         clamp
#       hand
#         chisel
#     view
#     lager
#     palette
#     architectural
#       blueprint
#     dry
#       wall
#         anchor
#     beer
#       peacock
#         machine
#           tool
#     drop
#       forge
#     film
#       motive
#         power
#           battery
#     river
#     weight
#     straight
#       saw
#     book
#       clasp
#       pres
#     blooming
#       mill
#     natural
#       power
#         source
#     smart
#       padlock
#     watered
#       cutting
#         machine
#     point
#     feel
#     keen
#       trachoma
#         l
#           surface
#             grinder
#       l
#         s
#           detach
#             werkzeugmuseum
#           recknagel
#     series
#       i
#     debut
#       tool
#     cigar
#       cutter
#     splash
#       shield
#     overall
#     distribution
#       box
#     lemon
#       squeezer
#     steady
#       rest
#     sound
#       protection
#     pepper
#       mill
#     ginger
#     tree
#       chipper
#     muse
#     poultry
#       shears
#     happy
#       flat
#         head
#           screwdriver
#       screwdriver
#     grape
#       processing
#         equipment
#     excellent
#       automation
#         csc
#           controller
#     fettle
#       perfecta
#         rotary
#           compacting
#             pres
#     fall
#       protection
#         harnes
#       harnes
#     buyer
#     boost
#     bowl
#     grit
#       disc
#     turn
#       lock
#     fine
#     school
#     depth
#     sum
#       d
#     many
#       image
#     early
#       century
#         factory
#     coconut
#       pres
#     well
#     prewar
#     narrow
#     winery
#     traditional
#       sharpening
#       hand
#         tool
#       pres
#       equipment
#     closeup
#     province
#     package
#     de
#       corbeilessonne
#     dinner
#     hallmark
#     sleeve
#       nut
#     lamb
#     globe
#     tea
#       lock
#     soft
#       mallet
#     polished
#       turbine
#         blade
#     investment
#       casting
#     flower
#     european
#       screw
#     forehead
#       screwdriver
#         bit
#     slick
#       chisel
#     par
#       lamp
#     groove
#       lock
#         pliers
#     total
#       station
#     match
#     habit
#       crane
#     swan
#       service
#     volume
#       tool
#     heart
#       lock
#     lower
#       fort
#         marry
#     brown
#       tape
#     indicator
#       panel
#     treble
#       hook
#     note
#       holder
#     eager
#       godsend
#     reflective
#       bulb
#     gauge
#     gage
#     caliper
#     oscilloscope
#     feeler
#     voltmeter
#     square
#     optometer
#     fissurometer
#     inspection
#     testing
#     measurement
#   fasteners
#     screw
#       driver
#         bit
#         tip
#         tool
#           kit
#         hex
#           bit
#       clamp
#       pump
#       pres
#       press
#       cap
#       eye
#         hook
#       head
#       lock
#       anchor
#       conveyor
#       box
#       connector
#       manufacturing
#         machine
#       jack
#       gun
#       bit
#     chainsaw
#       chain
#       chap
#       blade
#       pie
#       safety
#         clothing
#         link
#       tooth
#     screwdriver
#       set
#       bit
#       handle
#       end
#       multifoil
#     clamp
#       tool
#     bolt
#       cutter
#         head
#       extractor
#       thread
#       extraction
#         kit
#       gun
#     nut
#       hardware
#       tool
#         insert
#       driver
#     chisel
#     padlock
#       texture
#     bandsaw
#       metal
#       blade
#     pliers
#     carabiner
#       clip
#     netherland
#     wrench
#       bit
#         insert
#       set
#     goggle
#     miter
#       box
#     crucible
#       tong
#       metalworking
#       furnace
#     archimede
#       screw
#         water
#           pump
#     zipper
#       slider
#       merge
#       storage
#         bag
#     glas
#       worker
#         bench
#       mortar
#       blower
#       cutter
#       jar
#       teapot
#       plate
#     rasp
#     shears
#     hex
#       nut
#       head
#         bolt
#         lag
#           bolt
#         nut
#       bolt
#       bit
#         set
#       external
#       key
#       lock
#         nut
#       flange
#         nut
#       cap
#       lag
#         bolt
#       wrench
#       socket
#     fastener
#       head
#       identification
#       bit
#     crewmate
#       carabiner
#     clothespin
#     reamer
#     woodchopper
#     mallet
#     ladle
#       metallurgy
#       car
#       hook
#       carrier
#     adhesive
#       tape
#         corner
#         dispenser
#       container
#       dispenser
#       bandage
#       surgical
#         paper
#           tape
#     corkscrew
#       tool
#         basic
#           type
#         spiral
#           wine
#             opener
#     hacksaw
#       hand
#         tool
#       blade
#     rivet
#       gun
#       nut
#       tool
#       setter
#         rivet
#           pres
#       hand
#         tool
#       blank
#       pres
#     ga
#       tungsten
#       cylinder
#       tank
#       metal
#         arc
#           welding
#       welder
#       canister
#       torch
#       drilling
#       drill
#         hole
#         bit
#       welding
#       production
#       flame
#         welder
#         cutter
#       regulator
#       power
#         chainsaw
#     duct
#       tape
#         sword
#     diagonal
#       cutter
#       cutting
#         pliers
#     glue
#       gun
#       stick
#       container
#       dispenser
#       tube
#     handsaw
#     strap
#       buckle
#       tightener
#     jeweller
#       making
#       tool
#       bench
#       material
#     whetstone
#     brazing
#     vise
#       grip
#         pliers
#     solder
#       wire
#         spool
#       fitting
#       gun
#         stand
#         holder
#       iron
#       feedstock
#       sucker
#       cleaning
#       hot
#         air
#           gun
#       thermal
#         grease
#         paste
#       metal
#       control
#       power
#         supply
#       sponge
#       flux
#       paste
#     oxyacetylene
#       cutter
#       welding
#       welder
#       ga
#         welder
#         cutter
#       blowpipe
#       torch
#     pulley
#       crane
#         hook
#       hook
#       wheel
#     dreamer
#     paperclip
#     gravestone
#     makuta
#       cordles
#         power
#           drill
#       jigsaw
#       circular
#       chainsaw
#       belt
#         sander
#       jig
#       rotary
#         hammer
#       angle
#         grinder
#       sabre
#       rivet
#         tool
#       power
#         drill
#       concrete
#       drill
#     hibachi
#       circular
#     mig
#       welder
#         gun
#         head
#       weld
#       welding
#     bevel
#       gear
#       edge
#         chisel
#       system
#     ingot
#       mound
#       casting
#         machine
#     snip
#     drywall
#       anchor
#       plug
#     caliper
#     feeler
#       gauge
#         set
#       gage
#         set
#     sandpaper
#     sledge
#       hammer
#       axe
#     airscrew
#     sawhorse
#     micrometer
#       adjustment
#         knob
#     latch
#     flathead
#       screwdriver
#       precision
#         screwdriver
#       machine
#         screw
#     socket
#       wrench
#         bit
#       head
#         cap
#     scythe
#       sharpening
#     planer
#       sander
#     mangle
#     interlock
#     scissor
#       lift
#       jack
#     epoxy
#       resin
#         dispenser
#       dispenser
#       tube
#     protractor
#     collet
#       chuck
#     berretta
#       t
#     slovenia
#     nipper
#     turnbuckle
#       sailing
#     pallet
#       jack
#       lift
#     thread
#       tap
#       gauge
#         set
#       dy
#       locker
#       insert
#       die
#         handle
#       gage
#       measurement
#         place
#       tapper
#         tool
#     minu
#       driver
#     conveyor
#       belt
#       system
#     sledgehammer
#     threading
#     kob
#     cyanoacrylate
#       glue
#     masking
#       tape
#     mortise
#       chisel
#       machine
#     leidschendam
#     hardhat
#     tricorne
#       bit
#       drill
#     multimeter
#     dowel
#       nut
#       pin
#       rod
#     armlet
#       mill
#         industrial
#           museum
#     extruder
#     sharpener
#       gar
#     lug
#       bolt
#       nut
#     watchmaker
#       lathe
#       compas
#     tweezer
#     awl
#     caulk
#       gun
#     buckle
#     necklace
#     conveyer
#       belt
#       roller
#     obi
#       liana
#     spool
#       storage
#     hanger
#     mandala
#       myanmar
#     jointer
#     kobelco
#       c
#     revolute
#       gear
#         train
#     vernier
#       caliper
#     sherbert
#       machine
#         tool
#     shaper
#       woodworking
#     voltmeter
#     breadboard
#     hasp
#     kip
#       monument
#     donut
#     plow
#     albino
#       press
#       pres
#       printing
#         pres
#     olein
#       tool
#       steel
#     slicer
#     gimlet
#     fret
#     jeweler
#       screwdriver
#       bench
#     soldering
#       iron
#     headstock
#       assembly
#     coterie
#       riviera
#     sprocket
#     pruner
#     countersink
#     borehole
#       drilling
#     hoist
#     snowblower
#     broom
#       head
#     stubby
#       screwdriver
#       flat
#         blade
#           screwdriver
#     calender
#       series
#     dozer
#       blade
#     burr
#       grinder
#     wiz
#       diamond
#         router
#     flap
#       wheel
#       sander
#         disc
#       disc
#     bookbinding
#       pres
#     flange
#       nut
#       bolt
#     wailer
#       lathe
#     victorinox
#       swim
#         army
#       multifoil
#     pagination
#       stamp
#     whitworth
#       thread
#     filigree
#     visor
#     foldable
#       phone
#     mite
#       box
#       bond
#       fix
#       square
#     turnstone
#     snowplow
#     stair
#     scraper
#     silo
#     polisher
#     mufti
#       tool
#       axi
#         milling
#           machine
#       material
#         shredder
#     emery
#       cloth
#     movable
#       type
#     worktable
#     spline
#       cutter
#     butte
#     hyoid
#       bevel
#         gear
#     guillotine
#       sheet
#         metal
#     hilt
#       rotary
#         hammer
#       hammer
#         drill
#       angle
#         grinder
#     polystyrene
#       cutter
#       adhesive
#     dimple
#       key
#     catatonia
#     gouge
#     benchtop
#       grinder
#       vise
#       bandsaw
#       polisher
#     wheelbarrow
#     fingernail
#       clipper
#     manta
#     detach
#       museum
#     harp
#     stapler
#     deli
#     pickaxe
#     railcard
#       hitch
#     interrex
#       i
#     gaffer
#       tape
#     sack
#       roll
#     knob
#     carbide
#       insert
#       tool
#         insert
#       cutter
#         insert
#     allay
#       wrench
#         bit
#           insert
#     rijksmuseum
#       amsterdam
#     yehudit
#     joinery
#       machine
#     disassembled
#       power
#         drill
#     horseshoe
#     sealant
#     thibaut
#       ash
#         diamond
#           wire
#     festoon
#       t
#         ebb
#       circular
#       compound
#         miter
#       power
#         drill
#     bandage
#       shears
#     rug
#       loom
#     steelwork
#       machinery
#       pres
#     firebreak
#       clearing
#         machine
#     corban
#       russia
#     leister
#     masseuse
#       squish
#         doe
#           atelier
#             doe
#               capuchin
#     briquette
#       press
#       pres
#     chubby
#       security
#     rim
#       lock
#     andalusite
#     churchly
#       machine
#         tool
#           company
#     krypton
#       k
#     sumac
#       geisha
#     metalworker
#     thumb
#       tack
#       latch
#     posse
#       blockading
#         machine
#     warlock
#       interface
#     trencher
#     dockland
#       museum
#     pesqueira
#     coverall
#     pignut
#       tool
#         insert
#     putty
#       knife
#     weatherproof
#       wood
#         adhesive
#     brazier
#     mitutoyo
#       caliper
#       coordinate
#         measuring
#           machine
#     linocut
#       gouge
#     zodiac
#       northwest
#         snow
#           blower
#     crenshaw
#       pump
#     metrology
#       equipment
#       station
#       table
#     paraffin
#       gauze
#     coupler
#     faro
#       edge
#         robot
#           arm
#     cylindrical
#       tool
#       roller
#         bearing
#       pushpin
#     koto
#       beluga
#         angel
#     grate
#     clippers
#     microchip
#     goalpost
#     volva
#       excavator
#       crawler
#         excavator
#     dagger
#     mcconnel
#     deaden
#     eyeglass
#     knuckle
#     parrot
#     muzak
#       super
#         turbo
#           fiber
#             csc
#               laser
#                 cutter
#       interrex
#         i
#     opal
#     shim
#       set
#     kola
#       superdeep
#         borehole
#     borsch
#       tablet
#         pres
#     crowbar
#     telescoping
#       gage
#         case
#     multifunction
#     sandpit
#       ti
#       commando
#         dark
#           drill
#             rig
#     fishtail
#       drill
#         bit
#     kaka
#       robot
#         arm
#     chipper
#     sawbuck
#     ironworker
#       machine
#     gramophone
#       recorder
#     digger
#     keycard
#       reader
#     gar
#       belt
#         buckle
#       chubby
#         fire
#           unipolar
#             r
#     teapot
#     motorman
#       industrial
#         robot
#       robot
#     pantograph
#     wrist
#       watch
#     grease
#       seal
#     sizer
#     massachusett
#     butt
#       chisel
#     tricycle
#     loom
#     halon
#     tumbler
#     broach
#       bar
#     helicoid
#       insert
#     equipoise
#     trimmer
#     pincer
#       grip
#     flex
#       lead
#     headlight
#       window
#     trus
#     bellman
#       vtssu
#         adjustable
#           soldering
#             station
#     impregnation
#       system
#     hoe
#     leveler
#     pinion
#     deadbolt
#     grindstone
#     handcraft
#       grinder
#     gass
#     toggle
#       bolt
#         hook
#     cant
#       hook
#     sealing
#       tape
#     grater
#     spatula
#     kite
#       string
#     router
#     mouser
#       csc
#         lathe
#       m
#         lathe
#     stonemason
#       tool
#     nag
#       rivet
#         tool
#     knot
#     hexagon
#       screwdriver
#         bit
#     multicam
#     decanter
#       centrifuge
#     maillot
#     blacklight
#       bulb
#     gon
#     hammermill
#       machine
#     gutter
#     pegboard
#     clockmaker
#       compas
#     casagrande
#       b
#         crawler
#     archimedean
#       screw
#     finger
#     twine
#       roll
#     gutenberg
#       pres
#     bridgework
#       knee
#         mill
#     erlenmeyer
#       flask
#     tenon
#     yihui
#       video
#         measuring
#           system
#     matchstick
#     eyelet
#       pliers
#     gripper
#     phonograph
#       cutting
#         machine
#     toenail
#       cutter
#       clippers
#     wick
#       trimmer
#     transdermal
#       patch
#     ferrule
#     sepal
#     hook
#     pin
#     rail fastening
#   electrical
#     welder
#       mask
#       generator
#       helmet
#     excavator
#       claw
#         arm
#       shovel
#         bucket
#       drilling
#         rig
#       rock
#     incandescent
#       light
#         bulb
#           component
#       lightbulb
#     power
#       drill
#       tool
#         trigger
#       miter
#       hammer
#         drill
#         dy
#       supply
#       generator
#       sander
#       hacksaw
#       chisel
#       grinder
#       button
#       outlet
#       plant
#       jack
#       machinery
#       bit
#       stone
#         chisel
#       strip
#       cord
#       planer
#       fretsaw
#       tester
#       source
#     wire
#       cutter
#         military
#       stripper
#       stripping
#         scissors
#       crimp
#         ferrule
#       pulley
#         hook
#       brush
#       ferrule
#         crimper
#       wheel
#       spool
#       thimble
#       feeder
#       rope
#         clamp
#         clip
#       cutting
#         machine
#       solder
#       connection
#       em
#       coil
#       bundle
#       snip
#       wrap
#       cuter
#       crimper
#       bending
#         machine
#     tong
#     electric
#       drill
#         head
#       chainsaw
#       sander
#       hammer
#         drill
#       motor
#         rotor
#       hand
#         drill
#       screwdriver
#       vibratory
#         sander
#       grinder
#       miter
#       wrench
#       palm
#         sander
#       driver
#       discharge
#         machine
#       sniffer
#       current
#         detector
#       wiring
#       storage
#         vent
#       socket
#         wrench
#       scroll
#       relay
#       fan
#       bench
#         grinder
#       chain
#     spark
#       erosion
#         machine
#     pencil
#       sharpener
#     furnace
#       tong
#       bellow
#       structure
#     pipe
#       clamp
#       cutter
#       fitting
#       hanger
#       welder
#       lock
#       cleaning
#       maintenance
#       threader
#       bender
#     bulb
#     lightbulb
#     csc
#       machine
#         control
#           panel
#         tool
#         controller
#       lathe
#       controller
#         panel
#       router
#         table
#       mill
#         tool
#           changer
#       plasma
#         cutter
#         bevel
#           cutter
#       wood
#         router
#       milling
#         machine
#       laser
#         cutter
#       metal
#         lathe
#       panel
#       knee
#         mill
#       punching
#         machine
#       sheet
#         metal
#           bender
#       pipe
#         bending
#           machine
#       arc
#         welding
#           machine
#       machining
#         center
#       boring
#         mill
#       collet
#         tool
#           holder
#       tool
#         holder
#       indelible
#         tool
#           holder
#       horizontal
#         milling
#           machine
#       control
#         panel
#     heat
#       torch
#         power
#           supply
#       pres
#       resistant
#         coat
#       treatment
#       treat
#         furnace
#       cutter
#     rope
#       pulley
#         hook
#       storage
#     ruler
#       square
#     circuit
#       board
#     battery
#       charger
#     tractor
#     steam
#       hammer
#       saw
#       locomotive
#       train
#       roller
#       winch
#       engine
#         mechanism
#     orbital
#       sander
#       welding
#         machine
#       sheet
#         sander
#     hydraulic
#       press
#       extrication
#         cutter
#         cutterspreader
#       pres
#         control
#           vehicle
#       rescue
#         tool
#       cutter
#       auger
#       soil
#         auger
#       drill
#       boom
#         arm
#       forging
#         pres
#       die
#         pres
#       machine
#       crawler
#         pile
#           driver
#       steel
#         riveter
#       shears
#       excavator
#       drilling
#         rig
#       log
#         splitter
#       wood
#         splitter
#       power
#         tool
#     plasma
#       cutter
#       arc
#         cutter
#       torch
#         cutter
#       drilling
#     beam
#       system
#       stock
#     gauge
#       block
#       readout
#       finder
#     vertical
#       milling
#         machine
#       mill
#       drilling
#         rig
#         machine
#       bandsaw
#       mixer
#       machining
#         center
#           li
#       belt
#         sander
#       csc
#         milling
#           machine
#       boring
#         rig
#       turning
#         machine
#       band
#     electrical
#       component
#       circuit
#       tape
#       discharge
#         machining
#       equipment
#       relay
#       cabinet
#       motor
#       fuse
#       device
#       terminal
#       solder
#       machining
#         tool
#       test
#         bench
#       outlet
#     lamp
#       shade
#     forklift
#     overhead
#       gantry
#         bridge
#         ladle
#           carrier
#       crane
#       cabinet
#         hinge
#     l
#       bracket
#       square
#         ruler
#     rod
#     cable
#       tie
#         tool
#         gun
#       cutter
#       lacing
#       hoist
#     ear
#       muff
#       protection
#       plug
#       protector
#     generator
#     jackhammer
#     wind
#       mill
#     electrician
#       screwdriver
#       screw
#         driver
#     filament
#       light
#         bulb
#       lamp
#       bulb
#     jaw
#       chuck
#     directional
#       drilling
#     magnetic
#       drill
#         pres
#       bearing
#       base
#         drill
#           pres
#       drilling
#         machine
#       tapping
#         machine
#       drillingtapping
#         machine
#     tire
#       changer
#       quality
#         inspector
#       mounting
#         machine
#       machine
#     motor
#       vehicle
#     rig
#       machine
#       control
#         panel
#     cone
#       drill
#         bit
#     arc
#       cutter
#       welding
#       welder
#       machine
#       melter
#     wiring
#       device
#     coil
#       railway
#         wagon
#       steel
#         car
#     platen
#       press
#       pres
#       printing
#         pres
#     cutoff
#       saw
#     radio
#       fob
#     shaft
#       shredder
#     resistor
#     guitar
#       headstock
#       hanger
#     thumbtack
#     mechanical
#       pres
#       design
#       hand
#         drill
#       tool
#       mixer
#       engineering
#       jack
#       gear
#       pruning
#         equipment
#       cleaner
#       governor
#       gauge
#       component
#         diagram
#       pump
#       pencil
#         sharpener
#       measuring
#         tool
#       workshop
#       grinder
#     bungee
#       cord
#         hook
#       chord
#     lighting
#       component
#     vent
#       head
#     halogen
#       light
#         bulb
#     din
#     hose
#       clamp
#     fuse
#     friction
#       stir
#         welding
#         weld
#     adjustable
#       screwdriver
#         set
#       wrench
#       reamer
#       tool
#         handle
#       wireles
#         voltage
#           probe
#       screw
#         clamp
#       flat
#         head
#           screwdriver
#       miter
#       fret
#     connector
#     voltage
#       detector
#       tester
#       supply
#       sensor
#       probe
#     compactor
#     pneumatic
#       descale
#       drill
#       hammer
#         drill
#       nailer
#       grinder
#       tool
#       wrench
#       nail
#         gun
#       multifoil
#         bit
#       needle
#         scaler
#       impact
#         gun
#           chisel
#             insert
#       forging
#         hammer
#       riveter
#       rivet
#         gun
#       rock
#         drill
#     pole
#       lathe
#     welding
#       visor
#       torch
#       frame
#       proces
#     mcculloch
#       chainsaw
#     mitsubishi
#     siemens
#     vibratory
#       sander
#       tamper
#     pump
#       drill
#       system
#     cylinder
#       press
#       boring
#         machine
#       metal
#         billet
#       hone
#     thermal
#       lance
#     torque
#       screwdriver
#       seal
#     capacitor
#     string
#     tradesman
#       miter
#       compound
#         miter
#     colander
#     tiffin
#       studio
#         lampshade
#     kerosene
#       blow
#         torch
#     f
#       clamp
#       w
#     optical
#       microscope
#     telltale
#       crack
#         monitor
#     engineering
#       schematic
#       blueprint
#     electron
#       beam
#         welding
#           system
#     semiconductor
#       sample
#     centrifugal
#       casting
#     caster
#       wheel
#     brake
#     headphone
#       jack
#     acetylene
#       tank
#         storage
#       torch
#     oxygen
#       tank
#       tankacetylene
#         tank
#     hydrant
#       wrench
#     lumbar
#     surge
#       protector
#     pedal
#     barbed
#       wire
#     degree
#       angle
#         bracket
#         corner
#           square
#         brace
#       square
#     candle
#       snuffer
#     mast
#       mosh
#       rope
#     geotechnical
#       drilling
#         rig
#       equipment
#       engineering
#     insulator
#     chamberlain
#       key
#     engine
#       block
#       header
#       oil
#     hem
#       ha
#         horizontal
#           band
#     plug
#     sleeper
#       drilling
#         machine
#     rafter
#       square
#     morse
#       taper
#     hayride
#     operator
#     fluorescent
#       tube
#         light
#           bulb
#       light
#     hydropower
#       screw
#     splitter
#     boiler
#     solar
# ...
#       casting
#       tape
#       part
#       profile
#     rubber
#       mallet
#       mold
#       band
#         ball
#       stock
#       tire
#     iran
#       tractor
#         foundry
#           company
#     oil
#       rig
#       mill
#       press
#       platform
#       derrick
#       humpback
#       cake
#         mill
#       ga
#         water
#       seal
#       pres
#         machine
#       drill
#       well
#       drilling
#     manufacturing
#       proces
#       floor
#       surface
#       facility
#     brick
#       wall
#       saw
#       mason
#       factory
#         exterior
#     masonry
#       hole
#         cutter
#       saw
#       drill
#     torn
#       screw
#       bit
#       head
#         screwdriver
#           bit
#       screwdriver
#         bit
#       cheese
#         head
#           machine
#             screw
#       bolt
#     wool
#       shears
#     pottery
#       tool
#       workpiece
#     wrought
#       nail
#       iron
#         nail
#     tile
#       cutter
#     floor
#       pillar
#         drill
#       sander
#       light
#       polisher
#       buffer
#     textile
#       scissors
#       machine
#       equipment
#       manufacturing
#       factory
#       worker
#       facility
#     container
#       crane
#     ukraine
#     heavy
#       machinery
#         component
#     molten
#       metal
#         pot
#         trough
#       steel
#         ladle
#       glas
#     vial
#     material
#       mixer
#       hopper
#       handling
#     waterpower
#       trip
#         hammer
#           yekaterinburg
#     exhibition
#     r
#       razor
#       pin
#     centrifuge
#       vial
#       tube
#     resin
#       casting
#     bundle
#     slag
#       pot
#     silver
#       ingot
#       ring
#     liquid
#       nitrogen
#         tank
#     strainer
#     scrap
#       metal
#     cement
#       mixer
#         truck
#       production
#         machine
#       truck
#     mining
#       machine
#       drill
#         bit
#       tool
#       equipment
#     sheet
#       metal
#         punch
#         former
#         brake
#         bender
#         shaper
#         hole
#           punch
#         shears
#         shear
#         bending
#           machine
#     rust
#     copper
#       foil
#         glasswork
#       pipe
#         fitting
#     clay
#       workpiece
#     sugarcane
#       juice
#         machine
#     thick
#       metal
#         sheet
#     silicone
#       print
#         head
#     nylon
#       nut
#     porcelain
#       mortar
#     cover
#     underground
#       drill
#         rig
#       mining
#         machine
#     tungsten
#       carbide
#         draw
#           plate
#     soil
#       auger
#       drilling
#     exhibit
#     agricultural
#       tool
#       hose
#         reel
#     metalwork
#     feedstock
#     asphalt
#     alloy
#       padlock
#       key
#       lock
#     batch
#       mixer
#     science
#       museum
#     printed
#       circuit
#         board
#     funnel
#       hopper
#     land
#       drilling
#         rig
#     compound
#       rest
#       miter
#     wash
#       tape
#     waterproof
#       pa
#         building
#           adhesive
#     foam
#     spray
#       paint
#         gun
#     forestry
#       muncher
#     firewood
#       conveyor
#         belt
#     fabric
#       making
#         machine
#       processing
#       scissor
#       ruler
#     sticky
#       tack
#     unloaded
#     mass
#       steam
#         hammer
#           blaenavon
#           griffithstown
#     capture
#       nut
#     decorative
#       hinge
#       tape
#       metalwork
#       light
#         bulb
#     yarn
#     republic
#     worth
#       steel
#     other
#       part
#     suit
#     dye
#       cut
#         pres
#     garbage
#       disposal
#         unit
#     leather
#       punch
#     seam
#       tracker
#     foil
#       bearing
#     polycrystalline
#       sample
#     silicon
#       ingot
#     site
#       work
#       investigation
#     fabrication
#       shop
#     dust
#       mask
#     satin
#       lettertype
#     colored
#       tape
#         roll
#     ink
#       ball
#     furniture
#       hardware
#     czech
#       republic
#     jewelry
#       burnisher
#     bangladesh
#     exotic
#       semiconductor
#         sample
#     powder
#       container
#     corn
#       light
#         bulb
#     tobacco
#       processing
#     chemical
#       reaction
#       strip
#     ornate
#       metal
#     earth
#     ductile
#       iron
#     unidentified
#       lock
#     trash
#     mineral
#       oil
#     lie
#       light
#         bulb
#     ultraviolet
#       light
#         bulb
#     semi
#       truck
#     feed
#       wire
#     cloth
#       hanger
#     dirt
#       auger
#     index
#     tamper
#       proof
#     receipt
#       printer
#     slab
#       scissor
#         lift
#     atom
#       s
#     space
#       drill
#     composite
#     rope
#     rail
#     track
#   maintenance
#     drilling
#       rig
#       machine
#       jumbo
#       technology
#       equipment
#       operation
#       platform
#       excavator
#     drill
#       pres
#       bit
#       excavator
#       head
#       rig
#       pipe
#       gage
#       attachment
#       mandrel
#       chuck
#     worker
#       weld
#     train
#       track
#       rail
#       car
#         hitch
#       hitch
#       plow
#       pilot
#       connection
#       engine
#     sawmill
#       part
#       band
#     mill
#       chuck
#       collet
#       wheel
#       rotary
#         table
#       dy
#       tool
#       stone
#       cutter
#         bit
#       bit
#       chatham
#     demolition
#       shears
#       site
#       plier
#     construction
#       site
#       equipment
#       helmet
#       worker
#       machine
#         hydraulic
#           claw
#       machinery
#       crane
#       loader
#       work
#       hardware
#     termite
#       rail
#         welding
#         weld
#       weld
#         mold
#         box
#         equipment
#       welder
#       welding
#         crucible
#         mold
#       railway
#         weld
#     factory
#       floor
#       worker
#       exterior
#       lamp
#       equipment
#     rail
#       fastening
#         system
#       grinder
#       joint
#       grinding
#         machine
#       track
#         welding
#       car
#       bolt
#       weld
#       clamp
#       welding
#       tool
#       tamping
#         machine
#       spike
#       fastener
#       defect
#       vehicle
#       tie
#       road
#         maintenance
#           shop
#       worker
#       wheel
#       attachment
#         sprint
#       yard
#       cart
#       work
#         cart
#       head
#       gauge
#         block
#       buckling
#     cutting
#     station
#     railway
#       snow
#         thrower
#       maintenance
#         equipment
#         infrastructure
#         termite
#           weld
#       clamp
#       weld
#       fastener
#       rotary
#         snowplow
#       tool
#       fastening
#         system
#     farrier
#       tool
#     machinist
#       square
#     utility
#       vehicle
#       knife
#         blade
#       hole
#         cover
#       truck
#       cart
#       poll
#       equipment
#       installation
#     railroad
#       track
#         welder
#         fastener
#       welding
#       rail
#       snow
#       joint
#       joining
#       spike
#     dental
#       drill
#         head
#       casting
#       tool
#         bit
#       equipment
#     trip
#       hammer
#     millstone
#       crane
#       maintenance
#     aviation
#     hood
#     aircraft
#     clasp
#     locomotive
#     bicycle
#       frame
#       lock
#       block
#       rear
#         dérailleur
#           hanger
#       chain
#         lock
#       cable
#         lock
#       cotter
#         pin
#     yard
#     pub
#     apron
#     tram
#     fixture
#       tool
#       table
#     bridge
#     delay
#       oh
#     tower
#       crane
#       bell
#     hacienda
#       la
#         lacuna
#     street
#       sign
#       lamp
#     extension
#       cord
#       cable
#     royal
#       bras
#     woolwich
#     bike
#       lock
#       wheel
#       rack
#     pa
#       glue
#       admix
#         adhesive
#     spend
#     carriage
#       bolt
#     facility
#     overseer
#       woodchopper
#       navigator
#     marka
#       orbital
#         sander
#     parcel
#       box
#     closed
#       type
#         guitar
#           machine
#             head
#     transportation
#     maintenance
#       vehicle
#       hole
#         cover
#     spa
#     temporary
#       rivet
#     d
#       printer
#       level
#       lathe
#     pit
#     church
#       bell
#     wedding
#     lockout
#       ragout
#         board
#     spur
#     joint
#     road
#       compactor
#       sign
#     hopper
#       fed
#         grinder
#     foot
#       pedal
#     carpenter
#       chisel
#     lawn
#       mower
#       tractor
#     woodland
#     dock
#     tent
#       peg
#     airplane
#       fuselage
#       assembler
#     port
#     gibraltar
#     noncontact
#       voltage
#         detector
#     building
#       foundation
#     lull
#     farm
#       equipment
#     garage
#       door
#     wardrobe
#       hook
#     jet
#       edge
#     tunnel
#       boring
#         machine
#       borer
#     sewer
#       hole
#         cover
#       cover
#     housing
#       construction
#     military
#       identification
#         ukraine
#     axle
#     cleaning
#       machine
#     shipping
#       box
#     collar
#       stud
#     helicopter
#       hook
#     highland
#       main
#         line
#     grove
#       cutter
#     gearbox
#     terminal
#       block
#     rapid
#       universal
#         printer
#         inject
#           printer
#       garden
#         shredder
#     primary
#       mill
#     warehouse
#     resealable
#       bag
#     regular
#       drill
#         bit
#     routine
#       dish
#     company
#     permanent
#       marker
#     cod
#     streamline
#     deck
#     ventilation
#       hose
#     fireman
#       axe
#       control
#         valve
#     delta
#       shipmaster
#         thicknes
#           planer
#       band
#     stud
#       fastener
#     shrine
#       series
#         deluxe
#           tabletop
#             mill
#     cargo
#       hook
#     unit
#     freight
#       train
#     load
#     peat
#     replacement
#       blade
#     cemetery
#     watermill
#     roadwork
#     cattle
#       crush
#     shuttle
#       axi
#         csc
#           tool
#       csc
#         wheel
#           grinder
#     bed
#     barge
#     chimney
#     postal
#     ferry
#     bastion
#       hotel
#         card
#     repair
#     upkeep
#     threadlocker
#     operator
#     engineer
#     welder
#     crewmate
#     jeweller
#     desk
#     workbench
#     stand
#     control
#     robot
#     automated
#     process
#     computer numerical
#     transport
#     truck
#     vehicle
#     twowheeler
#   miscellaneous
#     pres
#       machine
#       letter
#         block
#     handbook
#     husqvarna
#       chainsaw
#       ga
#       circular
#       concrete
#       cold
#         saw
#       force
#         chainsaw
#     riveter
#     manhole
#       cover
#     dy
#     ply
#     bellow
#     fidget
#       spinner
#         production
#     forme
#       printing
#     muff
#     vossloh
#       rail
#         fastening
#     facemask
#     column
#     minibar
#       t
#     wrecker
#     tempura
#     harem
#     hay
#       hook
#     spaghetti
#     pecker
#       drill
#       rotary
#         hammer
#           drill
#     stanhope
#       press
#       pres
#     bandit
#       woodchopper
#       stump
#         grinder
#     fontenay
#       abbey
#         trip
#           hammer
#     dahl
#       packstation
#     banjo
#       bolt
#     mi
#     um
#       m
#     snog
#       snow
#     kinda
#       b
#         machining
#           center
#     gladstone
#       pottery
#         museum
#     ism
#       robotic
#         gantry
#           welder
#       computer
#     gateau
#     streamer
#       pattern
#     typeset
#       shop
#     brutish
#       rail
#         clas
#     pensioner
#     hush
#       simplex
#         dual
#           cone
#     pic
#       pipe
#         cutter
#     flapper
#       grinding
#         wheel
#     pe
#     kilo
#       gold
#         bar
#     vat
#     xiaomi
#       milia
#         electric
#           screwdriver
#     illustration
#     gringo
#       ti
#         spindle
#           boulder
#     obese
#       hammerschmiede
#         bad
#           oberdorf
#     pester
#     catalog
#     pyrene
#       company
#     collapsible
#       coat
#         hanger
#     sera
#       mobile
#         sawmill
#     schmalz
#       speedway
#         wire
#           bending
#             machine
#     dorfmuseum
#     industriedenkmal
#     wehrhahn
#     kailyard
#   cordles
#     power
#       drill
#       tool
#     electric
#       chainsaw
#   oxyfuel
#     welding
#     cutting
#   secateur
#   dheesterboom
#   glockengus
#   ewattingen
#   continuou
#     casting
#     miner
#     track
#     mining
#       machine
#   bucksaw
#   poelenburg
#   earmuff
#   jorum
#   steelprofile
#   frohnauer
#     hammer
#   skilsaw
#     circular
#       saw
#   enchain
#   pontmousson
#   roadheader
#   trephine
#   fissurometer
#   hammerschmiede
#     camp
#     i
#     mark
#       indersdorf
#         gon
#   letterpres
#   vakgemaal
#   pipecutter
#   lockouttagout
#   fishplate
#   energyefficient
#     bulb
#   marinoni
#     rotary
#       pres
#   tailstock
#     assembly
#   twoperson
#   fretsaw
#   burdaard
#   woltersum
#   naildrill
#   spinnenkop
#     wedderveer
#   pushpin
#   erkundungsbohrung
#   kalisalz
#   thumbscrew
#     torture
#     fastener
#   needlenose
#     pliers
#   bochumer
#     vermin
#   wireles
#     voltage
#       probe
#   dorfmuseum
#     unterammergau
#   rasper
#   telehandler
#   handbohrmaschine
#   kailyard
#   multifoil
#     interface
#   citru
#     juicer
#     lever
#       press
#   houtzaagmolen
#   scheuchzer
#     grizzly
#       s
#   lettertype
#   lopper
#   molcajete
#   sawbench
#   keyway
#   henrichshtte
#   smithingmark
#   oleomac
#     chainsaw
#     ga
#   buttonhook
#   scourtinerie
#     nylon
#   axi
#     bubble
#       level
#     milling
#       machine
#     robot
#       arm
#     csc
#       machine
#       grinder
#   rollerburnish
#     machine
#   optometer
#   bergbaumuseum
#     bad
#       ground
#   bandaid
#   frdermaschine
#     knesebeckschacht
#   matrice
#   gluestick
#   landschaftspark
#     duisburgnord
#   sawstop
#   burghhaamstede
#   handkreissge
#   threepoint
#     hitch
#       hook
#     pleural
#       test
#   pointelle
#   mortice
#     lock
#   descale
#   bystronic
#   weltevreden
#     ripen
#   multifid
#     screwdriver
#   yubikey
#   soudogaz
#     x
#   leafblower
#   railgrinder
#   heavyduty
#     mixer
#   putzmeister
#     solid
#       pump
#         system
#   veenpark
#   cowcatcher
#   laic
#     core
#   chamfering
#     machine
#   jwbamkin
#   seydelmann
#     meat
#       grinder
#   cutquik
#   weldingdroid
#     burgomaster
#       pipe
#         welder
#   multiedge
#     tool
#   balkhauser
#     gotten
#   threadlocker
#   industriedenkmal
#     riemenfallhmmer
#       breckerfeld
#   lasercut
#     product
#   teleworker
#   phalli
#     collection
#   countertype
#     saw
#   steelstamp
#   dragsaw
#   crosssectional
#     diagram
#     view
#   estop
#     button
#   twowheeler
#   ueckernagel
#   knigsallee
#   wasserkraftwerk
#     schwarze
#       lack
#   wehrhahn
#   hankwang
#     laser
#       cutting
#         machine
#     p
#       laser
#         cutter
#   smalcalda
#   qvarnstensgruvan
#     minnesfjllet
#       i
#         lung
#   brikettfabrik
#     sepia
#       dagoba
#   lexica
#     tool
#       sander
#   traintrack
#   dogotul
#     hollow
#       steel
#         punch
#   leadscrew
#   embosser
#   expeller
#     press
#   tervasaari
#     sawmill
#   zeziola
#     ditz
#       sheet
#         metal
#           former
#   tieback
#     drill
#       rig
#   rhatische
#     barn
#   rhtische
#     barn
#   ikegai
#     lathe
#   sidrurgique
#   plier
#   harnes
#   saneryigo
#     sh
#   burnisher
#   variou
#     tool
#       bit
#   buranathai
#     buddhi
#       image
#         foundry
#   grundodrill
#   mikromat
#     lochkreissgen
#   milline
#   heinou
#     e
#       mobile
#         chipper
#   dvrycourcouronne
#   epilog
#     laser
#       cutter
#   tecaprint
#     tax
#       pad
#         printing
#           machine
#   comealong
#   pockethole
#   crmaillre
#   boerenbont
#   marlite
#   pieralisi
#     major
#       decanter
#         centrifuge
#   fischerdbel
#   sheepsfoot
#     roller
#     compactor
#   thicknes
#     gauge
#     gage
#   toolchest
#   powermax
#     plasma
#       cutter
#   polsilver
#     stainles
#   nonelectric
#     caliper
#   springloaded
#     pincer
#       grip
#   oberbau
#     k
#   channellock
#     pliers
#   flexographic
#     printing
#       pres
#   zwiebelmuster
#   hexalobular
#     bit
#   radiu
#     roller
#   caribeaner
#   stainles
#     steel
#       tank
#   microburin
#   pentalobe
#   degaus
#     feinsilber
#       silver
#         ingot
#   frohnau
#     annabergbuchholz
#   handwheel
#   potraviny
#     czech
#       republic
#   antislip
#     tape
#   digipas
#   gravograph
#     l
#       laser
#         engraver
#   mokumegane
#   kaginawa
#   luftschutzlampe
#   treenail
#   wirecutter
#   vierkantsleutel
#   emersion
#     knife
#   toolbelt
#   bieleckie
#     many
#   lighbulb
#   tensncut
#     wire
#       tie
#         gun
#   grandam
#   reseating
#     machine
#   hardpoint
#   sleggveien
#   autoforge
#   wappenschmiede
#     elastin
#   shindaiwa
#     chainsaw
#   swingaway
#   acces
#     card
#   innersole
#     rand
#       sad
#         smooth
#           drum
#             compactor
#   vintagestyle
#     bulb
#   polypu
#     i
#   makeblock

# %%
# import pandas as pd
# import nltk
# from nltk.corpus import wordnet
# from tqdm import tqdm
# import gensim.downloader as api
# from gensim.models import KeyedVectors
# import numpy as np
# from scipy.spatial.distance import cosine
# from fuzzywuzzy import process

# # Load pre-trained word embeddings
# word_vectors = api.load("glove-wiki-gigaword-100")

# # Load your dataset
# df = pd.read_csv('final_data_exploration.csv')

# # Expanded manufacturing taxonomy
# manufacturing_taxonomy = {
#     "equipment": ["machine", "tool", "device", "gauge", "lamp", "filament", "wire", "desk", "station", "nut", "chipper", "sander", "grinder", "press", "CNC", "drill", "mixer", "saw", "chisel", "caliper", "bolt", "key", "stand", "hook", "pliers", "lathe", "oscilloscope", "feeler", "milling", "jack", "crane", "clamp", "screw", "gage", "mill", "cutter", "workbench", "mallet", "whiteout", "dispenser", "voltmeter", "chainsaw", "anvil", "horseshoe", "corkscrew", "vial", "pin", "wrench", "square"],
#     "process": ["manufacturing", "assembly", "fabrication", "casting", "printing", "welding", "chopping", "wiring", "foundry", "molding", "processing", "snow blower", "track hardware", "rail fastening", "grinding", "milling", "drilling", "cutting", "sawing", "pumping", "clinching", "imprinting", "stamping"],
#     "material": ["metal", "plastic", "composite", "brick", "wood", "rope", "ceramic", "mold", "steel", "material", "paint", "marble", "concrete", "rail", "track"],
#     "personnel": ["worker", "operator", "engineer", "welder", "crewmate", "jeweller"],
#     "quality": ["inspection", "testing", "measurement", "gage", "gauge"],
#     "safety": ["protection", "hazard", "precaution", "helmet", "muff", "protector", "light", "safety", "mask", "voltage detector", "cone", "interlock"],
#     "maintenance": ["repair", "upkeep", "sander", "grinder", "maintenance"],
#     "logistics": ["transport", "shipping", "truck", "vehicle", "utility", "clip", "carabiner"],
#     "automation": ["control", "CNC", "robot", "automated", "process", "computer numerical"],
#     "electrical": ["voltage", "power supply", "bulb", "halogen", "incandescent", "voltmeter"],
# }

# def analyze_label(label):
#     return label.lower().split()

# df['analyzed_labels'] = df['label'].apply(analyze_label)

# def find_most_similar_category(concept, categories, threshold=0.3):
#     if concept in word_vectors.key_to_index:
#         similarities = []
#         for category in categories:
#             if category in word_vectors.key_to_index:
#                 similarity = 1 - cosine(word_vectors[concept], word_vectors[category])
#                 if similarity > threshold:
#                     similarities.append((category, similarity))
#         if similarities:
#             return max(similarities, key=lambda x: x[1])[0]
#     return None

# def fuzzy_match(word, category_terms, threshold=80):
#     matches = process.extractBests(word, category_terms, score_cutoff=threshold)
#     return matches[0][0] if matches else None

# def map_to_taxonomy(concepts, taxonomy):
#     for i in range(len(concepts)):
#         # Check single words
#         concept = concepts[i]
        
#         # Direct match
#         for category, terms in taxonomy.items():
#             if concept in terms:
#                 return category
        
#         # Fuzzy match
#         for category, terms in taxonomy.items():
#             fuzzy_match_result = fuzzy_match(concept, terms)
#             if fuzzy_match_result:
#                 return category
        
#         # Word similarity
#         category = find_most_similar_category(concept, taxonomy.keys())
#         if category:
#             return category
        
#         # Check word combinations (for multi-word labels)
#         if i < len(concepts) - 1:
#             two_word_concept = concepts[i] + " " + concepts[i+1]
#             for category, terms in taxonomy.items():
#                 if two_word_concept in terms:
#                     return category
    
#     # Fallback: return the category with the highest average similarity
#     avg_similarities = []
#     for category, terms in taxonomy.items():
#         similarities = [word_vectors.similarity(concept, term) for concept in concepts for term in terms if concept in word_vectors.key_to_index and term in word_vectors.key_to_index]
#         if similarities:
#             avg_similarities.append((category, np.mean(similarities)))
    
#     if avg_similarities:
#         return max(avg_similarities, key=lambda x: x[1])[0]
    
#     return "unknown"

# df['taxonomy_label'] = df['analyzed_labels'].apply(lambda concepts: map_to_taxonomy(concepts, manufacturing_taxonomy))

# # Print statistics
# print(df['taxonomy_label'].value_counts(normalize=True))

# # Check remaining unknown labels
# unknown_labels = df[df['taxonomy_label'] == 'unknown']['label'].unique()
# print("\nSample of remaining 'unknown' labels:")
# print(unknown_labels[:20])  # Print first 20 unknown labels

# # Print absolute counts
# print("\nAbsolute counts:")
# print(df['taxonomy_label'].value_counts())
# Out:
# /home/trkosire/Factorynet/hack_env/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# taxonomy_label
# equipment      0.371443
# process        0.188404
# material       0.144886
# electrical     0.099567
# safety         0.057508
# quality        0.042402
# personnel      0.033389
# maintenance    0.024076
# automation     0.021158
# logistics      0.010944
# unknown        0.006223
# Name: proportion, dtype: float64
#
# Sample of remaining 'unknown' labels:
# ['tailstock' 'dorfmuseum unterammergau' 'cowcatcher' 'secateur' 'knurling'
#  'smithingmark' 'roadheader' 'threadlocker'
#  'industriedenkmal riemenfallhmmer breckerfeld' 'rasper' 'telehandler'
#  'damascening' 'trephine' 'dheesterboom' 'fissurometer' 'twowheeler'
#  'wehrhahn' 'enchain' 'optometer' 'kailyard']
#
# Absolute counts:
# taxonomy_label
# equipment      8655
# process        4390
# material       3376
# electrical     2320
# safety         1340
# quality         988
# personnel       778
# maintenance     561
# automation      493
# logistics       255
# unknown         145
# Name: count, dtype: int64

# %%
# import pandas as pd
# import nltk
# from nltk.corpus import wordnet
# from tqdm import tqdm
# import gensim.downloader as api
# from gensim.models import KeyedVectors
# import numpy as np
# from scipy.spatial.distance import cosine

# # Load pre-trained word embeddings
# word_vectors = api.load("glove-wiki-gigaword-100")

# # Load your dataset
# df = pd.read_csv('final_data_exploration.csv')

# # Expanded manufacturing taxonomy
# manufacturing_taxonomy = {
#     "equipment": ["machine", "tool", "device", "gauge", "lamp", "filament", "wire", "desk", "station", "nut", "chipper", "sander", "grinder", "press", "CNC", "drill", "mixer", "saw", "chisel", "caliper", "bolt", "key", "stand", "hook", "pliers", "lathe", "oscilloscope", "feeler", "milling", "jack", "crane", "clamp", "screw", "gage", "mill", "cutter", "workbench"],
#     "process": ["manufacturing", "assembly", "fabrication", "casting", "printing", "welding", "chopping", "wiring", "foundry", "molding", "processing", "snow blower", "track hardware", "rail fastening", "grinding", "milling", "drilling", "cutting", "sawing", "pumping"],
#     "material": ["metal", "plastic", "composite", "brick", "wood", "rope", "ceramic", "mold", "steel", "material", "paint", "marble", "concrete", "rail", "track"],
#     "personnel": ["worker", "operator", "engineer", "welder", "crewmate", "jeweller"],
#     "quality": ["inspection", "testing", "measurement", "gage", "gauge"],
#     "safety": ["protection", "hazard", "precaution", "helmet", "muff", "protector", "light", "safety", "mask", "voltage detector", "cone"],
#     "maintenance": ["repair", "upkeep", "sander", "grinder", "maintenance"],
#     "logistics": ["transport", "shipping", "truck", "vehicle", "utility", "clip", "carabiner"],
#     "automation": ["control", "CNC", "robot", "automated", "process", "computer numerical"],
#     "electrical": ["voltage", "power supply", "bulb", "halogen", "incandescent"],
# }

# def analyze_label(label):
#     tokens = nltk.word_tokenize(label.lower())
#     return tokens

# df['analyzed_labels'] = df['label'].apply(analyze_label)

# def find_most_similar_category(concept, categories, threshold=0.3):
#     if concept in word_vectors.key_to_index:
#         similarities = []
#         for category in categories:
#             if category in word_vectors.key_to_index:
#                 similarity = 1 - cosine(word_vectors[concept], word_vectors[category])
#                 if similarity > threshold:
#                     similarities.append((category, similarity))
#         if similarities:
#             return max(similarities, key=lambda x: x[1])[0]
#     return None

# def map_to_taxonomy(concepts, taxonomy):
#     for concept in concepts:
#         # First, check if the concept is directly in any category
#         for category, terms in taxonomy.items():
#             if concept in terms:
#                 return category
        
#         # If not, use word similarity
#         category = find_most_similar_category(concept, taxonomy.keys())
#         if category:
#             return category
        
#         # If still no match, check similarity with terms in each category
#         for category, terms in taxonomy.items():
#             for term in terms:
#                 if find_most_similar_category(concept, [term], threshold=0.5):
#                     return category
    
#     return "unknown"

# df['taxonomy_label'] = df['analyzed_labels'].apply(lambda concepts: map_to_taxonomy(concepts, manufacturing_taxonomy))

# # Print statistics
# print(df['taxonomy_label'].value_counts(normalize=True))

# # Check remaining unknown labels
# unknown_labels = df[df['taxonomy_label'] == 'unknown']['label'].unique()
# print("\nSample of remaining 'unknown' labels:")
# print(unknown_labels[:20])  # Print first 20 unknown labels

# %%
# import pandas as pd
# import nltk
# from nltk.corpus import wordnet
# from tqdm import tqdm
# import gensim.downloader as api
# from gensim.models import KeyedVectors
# import numpy as np
# from scipy.spatial.distance import cosine

# # Download necessary NLTK data
# # nltk.download('wordnet')
# # nltk.download('averaged_perceptron_tagger')

# # Load pre-trained word embeddings
# # print("Loading word embeddings...")
# word_vectors = api.load("glove-wiki-gigaword-100")

# # Load your dataset
# df = pd.read_csv('final_data_exploration.csv')

# # Define a basic manufacturing taxonomy
# manufacturing_taxonomy = {
#     "equipment": ["machine", "tool", "device", "gauge", "lamp", "filament", "wire", "desk", "station", "nut", "chipper", "sander", "grinder", "press", "CNC", "drill", "mixer", "saw", "chisel", "caliper", "bolt", "key", "stand", "hook", "pliers", "lathe", "oscilloscope"],
#     "process": ["manufacturing", "assembly", "fabrication", "casting", "printing", "welding", "chopping", "wiring", "foundry", "molding", "processing", "snow blower", "track hardware", "rail fastening"],
#     "material": ["metal", "plastic", "composite", "brick", "wood", "rope", "ceramic", "mold", "steel", "material", "paint", "marble"],
#     "personnel": ["worker", "operator", "engineer", "welder", "crewmate"],
#     "quality": ["inspection", "testing", "measurement", "gage"],
#     "safety": ["protection", "hazard", "precaution", "helmet", "muff", "protector", "light", "safety", "mask", "voltage detector"],
#     "maintenance": ["repair", "upkeep", "sander", "grinder", "maintenance"],
#     "logistics": ["transport", "shipping", "truck", "vehicle", "utility", "clip"],
#     "automation": ["control", "CNC", "robot", "automated", "process"],
# }


# # Step 1: Label Analysis
# def analyze_label(label):
#     tokens = nltk.word_tokenize(label)
#     pos_tags = nltk.pos_tag(tokens)
    
#     concepts = []
#     current_concept = []
    
#     for word, pos in pos_tags:
#         if pos.startswith('NN') or pos.startswith('JJ'):
#             current_concept.append(word.lower())
#         else:
#             if current_concept:
#                 concepts.append(' '.join(current_concept))
#                 current_concept = []
    
#     if current_concept:
#         concepts.append(' '.join(current_concept))
    
#     return concepts

# df['analyzed_labels'] = df['label'].apply(analyze_label)

# # Step 2: Taxonomy Creation
# class TaxonomyNode:
#     def __init__(self, name):
#         self.name = name
#         self.children = {}
    
#     def add_child(self, child_name):
#         if child_name not in self.children:
#             self.children[child_name] = TaxonomyNode(child_name)
#         return self.children[child_name]

# root = TaxonomyNode('root')

# # Initialize the taxonomy with the manufacturing-specific categories
# for category in manufacturing_taxonomy.keys():
#     root.add_child(category)

# # Create a frequency dictionary for concepts
# concept_freq = {}
# for concepts in df['analyzed_labels']:
#     for concept in concepts:
#         concept_freq[concept] = concept_freq.get(concept, 0) + 1

# # Sort concepts by frequency
# sorted_concepts = sorted(concept_freq.items(), key=lambda x: x[1], reverse=True)

# # Function to find the most similar category
# def find_most_similar_category(concept, categories):
#     if concept in word_vectors.key_to_index:
#         similarities = [
#             (category, 1 - cosine(word_vectors[concept], word_vectors[category]))
#             for category in categories
#             if category in word_vectors.key_to_index
#         ]
#         if similarities:
#             return max(similarities, key=lambda x: x[1])[0]
#     return None

# # Create taxonomy based on frequency, word similarity, and manufacturing categories
# for concept, _ in sorted_concepts:
#     parts = concept.split()
#     current_node = root
#     for part in parts:
#         # Check if the part fits into any existing manufacturing category
#         category = find_most_similar_category(part, manufacturing_taxonomy.keys())
#         if category and category in current_node.children:
#             current_node = current_node.children[category]
#         current_node = current_node.add_child(part)

# # Add subcategories to their respective categories
# for category, subcategories in manufacturing_taxonomy.items():
#     category_node = root.children[category]
#     for subcategory in subcategories:
#         if subcategory not in category_node.children:
#             category_node.add_child(subcategory)


# df['analyzed_labels'] = df['label'].apply(analyze_label)


# # If there are common terms that should be categorized, we can add them to the taxonomy
# # change the labels with the manufacturing_taxonomy there should be in total  5 labels
# # equipment, process, material, personnel, quality, safety
# # for example machine should be equipment, manufacturing should be process, metal should be material, worker should be personnel, inspection should be quality, protection should be safety
# # Function to find the most similar category
# def find_most_similar_category(concept, categories):
#     if concept in word_vectors.key_to_index:
#         similarities = []
#         for category in categories:
#             if category in word_vectors.key_to_index:
#                 similarity = 1 - cosine(word_vectors[concept], word_vectors[category])
#                 similarities.append((category, similarity))
#         if similarities:
#             return max(similarities, key=lambda x: x[1])[0]
#     return None

# # Function to map labels to the closest manufacturing taxonomy category
# def map_to_taxonomy(concepts, taxonomy):
#     for concept in concepts:
#         category = find_most_similar_category(concept, taxonomy.keys())
#         if category:
#             return category
#     return "unknown"  # If no match found, return 'unknown' or any default label

# # Update the DataFrame with the new labels
# df['taxonomy_label'] = df['analyzed_labels'].apply(lambda concepts: map_to_taxonomy(concepts, manufacturing_taxonomy))

# %%
df
# Out:
#                                       label   x1   y1  height   width  \
# 0                  railway grinding machine  0.0  0.0   720.0   720.0
# 1                              rail grinder  0.0  0.0   720.0   720.0
# 2                  rail grinder with worker  0.0  0.0   720.0   720.0
# 3      railway grinding machine with worker  0.0  0.0   720.0   720.0
# 4                                    worker  0.0  0.0   720.0   720.0
# ...                                     ...  ...  ...     ...     ...
# 23296                             minibar t  0.0  0.0  2660.0  4000.0
# 23297                            rail clamp  0.0  0.0   605.0   907.0
# 23298                 patrol rail fastening  0.0  0.0  2304.0  3456.0
# 23299                             drill bit  0.0  0.0   651.0   907.0
# 23300                      percussion drill  0.0  0.0   762.0  1062.0
#
#           source      file_name             analyzed_labels taxonomy_label
# 0           user  1711591656377          [railway, machine]    maintenance
# 1           user  1711591656377              [rail grinder]        unknown
# 2           user  1711591656377      [rail grinder, worker]    maintenance
# 3           user  1711591656377  [railway, machine, worker]    maintenance
# 4           user  1711591656377                    [worker]    maintenance
# ...          ...            ...                         ...            ...
# 23296  wikimedia  1711580020679                 [minibar t]        unknown
# 23297       user  1711581093292                [rail clamp]        unknown
# 23298  wikimedia  1711581093292     [patrol rail fastening]        unknown
# 23299       user  1711566352395                       [bit]        quality
# 23300  wikimedia  1711566352395          [percussion drill]        unknown
#
# [23301 rows x 9 columns]

# %%
df['taxonomy_label'].value_counts()
# Out:
# taxonomy_label
# unknown        11704
# automation      2592
# equipment       2343
# material        1957
# process         1786
# maintenance      938
# safety           919
# quality          846
# personnel        125
# logistics         91
# Name: count, dtype: int64

# %%
# Check a sample of the 'unknown' labels to understand why they weren't matched
unknown_labels = df[df['taxonomy_label'] == 'unknown']['label'].unique()
print("Sample of 'unknown' labels:")
print(unknown_labels[:100])  # Print first 50 unknown labels
# Out:
# Sample of 'unknown' labels:
# ['rail grinder' 'railgrinder of the united state' 'ceramic mold'
#  'feeler gage' 'feeler gauge' 'milling machine'
#  'computer numerical control' 'printing pres' 'marinoni rotary pres cam'
#  'wood drill' 'work desk' 'work station' 'paint bottle' 'ear muff'
#  'hearing protector' 'desk lamp' 'jeweller bench' 'wood chipper'
#  'traffic cone' 'square nut' 'utility vehicle' 'jack stand' 'scissor jack'
#  'crane hook' 'safety helmet' 'grinder spark' 'door handle' 'door lock'
#  'from woltersum' 'steel foundry' 'ladle metallurgy' 'hand sander'
#  'random orbital sander' 'angle grinder' 'light bulb' 'halogen light bulb'
#  'incandescent light bulb' 'machine screw' 'gage block' 'gauge block'
#  'portable hand coffee mill' 'hand tool' 'outside caliper' 'hand chisel'
#  'hack saw' 'c clamp' 'try square' 'industrial machine' 'vertical mixer'
#  'heavyduty mixer' 'material mixer' 'industrial processor' 'batch mixer'
#  'mechanical mixer' 'casting machine' 'chamberlain key' 'correction tape'
#  'cold saw' 'husqvarna circular saw' 'husqvarna concrete saw'
#  'husqvarna cold saw' 'ear protector' 'robotic big welder'
#  'ga tungsten arc welding' 'steel bell' 'angle grinder disc'
#  'milwaukee noncontact voltage detector' 'noncontact voltage detector'
#  'voltage detector' 'railroad snow blower' 'snow blower'
#  'railway snow thrower' 'diagonal cutting pliers'
#  'knife reinforce diagonal wire cutter' 'railroad track'
#  'rail fastening system' 'rail joint' 'rail welding' 'track maintenance'
#  'railway infrastructure' 'metal rail' 'track hardware' 'rail fastening'
#  'carabiner clip' 'carabiner clip with screw lock' 'crewmate carabiner'
#  'lathe operator' 'power supply' 'voltage supply' 'electronic workbench'
#  'hand clamp' 'jeweller making' 'screw driver' 'minu driver'
#  'putzmeister solid pump system' 'pump system' 'saw blade' 'liebherr la'
#  'fish hook' 'fishing hook']
